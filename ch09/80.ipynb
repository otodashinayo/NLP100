# %%
from os import path, mkdir
import pandas as pd
from itertools import chain
from collections import Counter
import json

base = "/content/drive/MyDrive/NLP100/ch09"

fp = "NewsAggregatorDataset/newsCorpora.csv"
names = ["ID", "TITLE", "URL", "PUBLISHER", "CATEGORY", "STORY", "HOSTNAME", "TIMESTAMP"]
df = pd.read_csv(path.join(base, fp), sep="\t", index_col=0, names=names)
df = df[(df["PUBLISHER"] == "Reuters") | (df["PUBLISHER"] == "Huffington Post") | (df["PUBLISHER"] == "Businessweek") | (df["PUBLISHER"] == "Contactmusic.com") | (df["PUBLISHER"] == "Daily Mail")]
df["CATEGORY"] = df["CATEGORY"].replace({"b": 0, "t": 1, "e": 2, "m": 3})
df.head()
# Out:
#                                                 TITLE  ...      TIMESTAMP
# ID                                                     ...
# 13       Europe reaches crunch point on banking union  ...  1394470501755
# 14  ECB FOCUS-Stronger euro drowns out ECB's messa...  ...  1394470501948
# 20  Euro Anxieties Wane as Bunds Top Treasuries, S...  ...  1394470503148
# 21  Noyer Says Strong Euro Creates Unwarranted Eco...  ...  1394470503366
# 30  REFILE-Bad loan triggers key feature in ECB ba...  ...  1394470505070
#
# [5 rows x 7 columns]

# %%
if not path.isdir(path.join(base, "80")):
  mkdir(path.join(base, "80"))
df = df.sample(frac=1, random_state=0)
df_train = df[:int(len(df) * 0.8)]
df_train.to_csv(path.join(base, "80/train.csv"))
df_valid = df[int(len(df) * 0.8):int(len(df) * 0.9)]
df_valid.to_csv(path.join(base, "80/valid.csv"))
df_test = df[int(len(df) * 0.9):]
df_test.to_csv(path.join(base, "80/test.csv"))

# %%
words_in_title = chain.from_iterable([title.split() for title in df_train["TITLE"]])
word_ids = {word: i + 1 for i, (word, count) in enumerate(Counter(words_in_title).most_common()) if count >= 2}
if not path.isdir(path.join(base, "80")):
  mkdir(path.join(base, "80"))
json.dump(word_ids, open(path.join(base, "80/word_ids.json"), "w"))


def title_to_ids(t):
  return [word_ids[w] if w in word_ids.keys() else 0 for w in t.split()]


title_to_ids("Europe reaches crunch point on banking union")
# Out:
# [252, 2031, 0, 1500, 4, 5640, 3980]
