# %%
from os import path
import json
import pandas as pd
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torch.optim import SGD
from torch.optim.lr_scheduler import ExponentialLR
import matplotlib.pyplot as plt

base = "/content/drive/MyDrive/NLP100/ch09"

fp_train = "80/train.csv"
fp_valid = "80/valid.csv"
fp_words = "80/word_ids.json"
df_train = pd.read_csv(path.join(base, fp_train), index_col=0)
df_valid = pd.read_csv(path.join(base, fp_valid), index_col=0)
word_ids = json.load(open(path.join(base, fp_words), "r"))
df_train.head()
# Out:
#                                                     TITLE  ...      TIMESTAMP
# ID                                                         ...
# 311098  RPT-Fitch Updates EMEA Consumer ABS Rating Cri...  ...  1403633888597
# 49198   Gurlitt Wants to Return Nazi-Looted Art, Suedd...  ...  1395886231417
# 410578  UPDATE 1-Fairfax Financial, CEO probed over po...  ...  1406929609070
# 270668  Angelina Jolie - Angelina Jolie Will Not Tight...  ...  1401828902205
# 301656  Patent Officials Cancel the Washington Redskin...  ...  1403113194649
#
# [5 rows x 7 columns]

# %%
num_words_of_title = max([len(title.split()) for title in df_train["TITLE"]])


def title_to_ids(t):
  res = [0 for _ in range(num_words_of_title)]
  for i, w in enumerate(t.split()):
    if w in word_ids.keys():
      res[i] = word_ids[w]
  return res


title_to_ids("Europe reaches crunch point on banking union")[:5]
# Out:
# [252, 2031, 0, 1500, 4]

# %%
X_train = torch.tensor([title_to_ids(title) for title in df_train["TITLE"]])
y_train = torch.tensor(df_train["CATEGORY"].values.astype("int"))
X_valid = torch.tensor([title_to_ids(title) for title in df_valid["TITLE"]])
y_valid = torch.tensor(df_valid["CATEGORY"].values.astype("int"))
print(X_train[:5])
# Out:
# tensor([[ 599, 3939,    0,  ...,    0,    0,    0],
#         [6646,  515,    1,  ...,    0,    0,    0],
#         [   7,    0, 6648,  ...,    0,    0,    0],
#         [ 326,  419,    6,  ...,    0,    0,    0],
#         [1521, 1382, 2762,  ...,    0,    0,    0]])

# %%
batch_size = 16
num_workers = 2
dataset_train = [(X_i, y_i) for X_i, y_i in zip(X_train, y_train)]
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True, num_workers=num_workers)
dataset_valid = [(X_i, y_i) for X_i, y_i in zip(X_valid, y_valid)]
dataloader_valid = DataLoader(dataset_valid, batch_size=batch_size, shuffle=True, num_workers=num_workers)

# %%
num_embeddings = max(word_ids.values()) + 1
embedding_dim = 300
hidden_size = 100
kernel_size = 11
stride = 1
padding = 5

class Model(nn.Module):
  def __init__(self):
    super().__init__()
    self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_idx=0)
    self.conv2d = nn.Conv2d(1, out_channels=hidden_size, kernel_size=(kernel_size, embedding_dim), stride=stride, padding=(padding, 0))
    self.relu = nn.ReLU()
    self.maxpool1d = nn.MaxPool1d(num_words_of_title)
    self.linear = nn.Linear(hidden_size, 4)
    self.softmax = nn.Softmax(dim=1)
    
  def forward(self, x):
    y = self.embedding(x)
    y = self.conv2d(y.unsqueeze(1))
    y = self.relu(y.squeeze(3))
    y = self.maxpool1d(y)
    y = self.linear(y.squeeze(2))
    y = self.softmax(y)
    return y

if torch.cuda.is_available():
  device = "cuda"
else:
  device = "cpu"
print(f"device: {device}")
model = Model().to(device)
print(model)
# Out:
# device: cuda
# Model(
#   (embedding): Embedding(10272, 300, padding_idx=0)
#   (conv2d): Conv2d(1, 100, kernel_size=(11, 300), stride=(1, 1), padding=(5, 0))
#   (relu): ReLU()
#   (maxpool1d): MaxPool1d(kernel_size=201, stride=201, padding=0, dilation=1, ceil_mode=False)
#   (linear): Linear(in_features=100, out_features=4, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %%
learning_rate = 0.05
loss_fn = nn.CrossEntropyLoss()
optimizer = SGD(model.parameters(), lr=learning_rate)
scheduler = ExponentialLR(optimizer, gamma=0.95)

loss_train = []
correct_train = []
loss_valid = []
correct_valid = []

for epoch in range(100):
  print(f"Epoch {epoch + 1}\n-------------------------------")
  size = len(dataloader_train.dataset)
  for batch, (X, y) in enumerate(dataloader_train):
    X, y = X.to(device), y.to(device)
    loss = loss_fn(model(X), y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if batch % 1000 == 0:
      loss, current = loss.item(), batch * len(X)
      print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
  scheduler.step()

  size = len(dataloader_train.dataset)
  loss, correct = 0, 0
  with torch.no_grad():
    for X, y in dataloader_train:
      X, y = X.to(device), y.to(device)
      pred = model(X)
      loss += loss_fn(pred, y).item()
      correct += (pred.argmax(1) == y).type(torch.float).sum().item()
  loss /= size
  correct /= size
  loss_train.append(loss)
  correct_train.append(correct)

  size = len(dataloader_valid.dataset)
  loss, correct = 0, 0
  with torch.no_grad():
    for X, y in dataloader_valid:
      X, y = X.to(device), y.to(device)
      pred = model(X)
      loss += loss_fn(pred, y).item()
      correct += (pred.argmax(1) == y).type(torch.float).sum().item()
  loss /= size
  correct /= size
  loss_valid.append(loss)
  correct_valid.append(correct)
  print(f"Test Error: \n Accuracy: {(100 * correct):>0.1f}%, Avg loss: {loss:>8f} \n")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.328746  [    0/10672]
# Test Error:
#  Accuracy: 72.6%, Avg loss: 0.064479
#
# Epoch 2
# -------------------------------
# loss: 0.919929  [    0/10672]
# Test Error:
#  Accuracy: 73.9%, Avg loss: 0.063261
#
# Epoch 3
# -------------------------------
# loss: 0.987071  [    0/10672]
# Test Error:
#  Accuracy: 74.4%, Avg loss: 0.062938
#
# Epoch 4
# -------------------------------
# loss: 0.810233  [    0/10672]
# Test Error:
#  Accuracy: 75.1%, Avg loss: 0.062677
#
# Epoch 5
# -------------------------------
# loss: 0.922815  [    0/10672]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.062666
#
# Epoch 6
# -------------------------------
# loss: 0.864101  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062821
#
# Epoch 7
# -------------------------------
# loss: 0.983909  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.063151
#
# Epoch 8
# -------------------------------
# loss: 0.837144  [    0/10672]
# Test Error:
#  Accuracy: 73.4%, Avg loss: 0.063659
#
# Epoch 9
# -------------------------------
# loss: 0.991888  [    0/10672]
# Test Error:
#  Accuracy: 73.3%, Avg loss: 0.063424
#
# Epoch 10
# -------------------------------
# loss: 0.903137  [    0/10672]
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.062670
#
# Epoch 11
# -------------------------------
# loss: 0.747312  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062377
#
# Epoch 12
# -------------------------------
# loss: 0.800922  [    0/10672]
# Test Error:
#  Accuracy: 75.7%, Avg loss: 0.062327
#
# Epoch 13
# -------------------------------
# loss: 0.745473  [    0/10672]
# Test Error:
#  Accuracy: 72.9%, Avg loss: 0.064387
#
# Epoch 14
# -------------------------------
# loss: 0.815488  [    0/10672]
# Test Error:
#  Accuracy: 73.0%, Avg loss: 0.064105
#
# Epoch 15
# -------------------------------
# loss: 0.783398  [    0/10672]
# Test Error:
#  Accuracy: 73.0%, Avg loss: 0.063896
#
# Epoch 16
# -------------------------------
# loss: 0.750432  [    0/10672]
# Test Error:
#  Accuracy: 71.7%, Avg loss: 0.063959
#
# Epoch 17
# -------------------------------
# loss: 0.748929  [    0/10672]
# Test Error:
#  Accuracy: 73.7%, Avg loss: 0.063431
#
# Epoch 18
# -------------------------------
# loss: 0.813790  [    0/10672]
# Test Error:
#  Accuracy: 73.5%, Avg loss: 0.063416
#
# Epoch 19
# -------------------------------
# loss: 0.807857  [    0/10672]
# Test Error:
#  Accuracy: 74.3%, Avg loss: 0.063084
#
# Epoch 20
# -------------------------------
# loss: 0.796934  [    0/10672]
# Test Error:
#  Accuracy: 74.3%, Avg loss: 0.063085
#
# Epoch 21
# -------------------------------
# loss: 0.748119  [    0/10672]
# Test Error:
#  Accuracy: 74.3%, Avg loss: 0.063222
#
# Epoch 22
# -------------------------------
# loss: 0.812111  [    0/10672]
# Test Error:
#  Accuracy: 74.5%, Avg loss: 0.062904
#
# Epoch 23
# -------------------------------
# loss: 0.744991  [    0/10672]
# Test Error:
#  Accuracy: 74.5%, Avg loss: 0.062804
#
# Epoch 24
# -------------------------------
# loss: 0.748227  [    0/10672]
# Test Error:
#  Accuracy: 74.6%, Avg loss: 0.062815
#
# Epoch 25
# -------------------------------
# loss: 0.812485  [    0/10672]
# Test Error:
#  Accuracy: 74.6%, Avg loss: 0.062605
#
# Epoch 26
# -------------------------------
# loss: 0.747572  [    0/10672]
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.062642
#
# Epoch 27
# -------------------------------
# loss: 0.744963  [    0/10672]
# Test Error:
#  Accuracy: 74.6%, Avg loss: 0.062558
#
# Epoch 28
# -------------------------------
# loss: 0.747491  [    0/10672]
# Test Error:
#  Accuracy: 74.6%, Avg loss: 0.062587
#
# Epoch 29
# -------------------------------
# loss: 0.745005  [    0/10672]
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.062499
#
# Epoch 30
# -------------------------------
# loss: 0.744994  [    0/10672]
# Test Error:
#  Accuracy: 74.6%, Avg loss: 0.062525
#
# Epoch 31
# -------------------------------
# loss: 0.744827  [    0/10672]
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.062382
#
# Epoch 32
# -------------------------------
# loss: 0.744700  [    0/10672]
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.062467
#
# Epoch 33
# -------------------------------
# loss: 0.745395  [    0/10672]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 0.062442
#
# Epoch 34
# -------------------------------
# loss: 0.744401  [    0/10672]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 0.062407
#
# Epoch 35
# -------------------------------
# loss: 0.744521  [    0/10672]
# Test Error:
#  Accuracy: 74.8%, Avg loss: 0.062388
#
# Epoch 36
# -------------------------------
# loss: 0.745580  [    0/10672]
# Test Error:
#  Accuracy: 74.8%, Avg loss: 0.062408
#
# Epoch 37
# -------------------------------
# loss: 0.744736  [    0/10672]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 0.062427
#
# Epoch 38
# -------------------------------
# loss: 0.744375  [    0/10672]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 0.062322
#
# Epoch 39
# -------------------------------
# loss: 0.744435  [    0/10672]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 0.062339
#
# Epoch 40
# -------------------------------
# loss: 0.744529  [    0/10672]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 0.062342
#
# Epoch 41
# -------------------------------
# loss: 0.807978  [    0/10672]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.062223
#
# Epoch 42
# -------------------------------
# loss: 0.869333  [    0/10672]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.062457
#
# Epoch 43
# -------------------------------
# loss: 0.806781  [    0/10672]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.062378
#
# Epoch 44
# -------------------------------
# loss: 0.745026  [    0/10672]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.062159
#
# Epoch 45
# -------------------------------
# loss: 0.745430  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062341
#
# Epoch 46
# -------------------------------
# loss: 0.746081  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062283
#
# Epoch 47
# -------------------------------
# loss: 0.744434  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062262
#
# Epoch 48
# -------------------------------
# loss: 0.744556  [    0/10672]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.062211
#
# Epoch 49
# -------------------------------
# loss: 0.744340  [    0/10672]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.062104
#
# Epoch 50
# -------------------------------
# loss: 0.744604  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062184
#
# Epoch 51
# -------------------------------
# loss: 0.745458  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062067
#
# Epoch 52
# -------------------------------
# loss: 0.745844  [    0/10672]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.062091
#
# Epoch 53
# -------------------------------
# loss: 0.744492  [    0/10672]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.062196
#
# Epoch 54
# -------------------------------
# loss: 0.745002  [    0/10672]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.062152
#
# Epoch 55
# -------------------------------
# loss: 0.744249  [    0/10672]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.062119
#
# Epoch 56
# -------------------------------
# loss: 0.744153  [    0/10672]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.062083
#
# Epoch 57
# -------------------------------
# loss: 0.744824  [    0/10672]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.062144
#
# Epoch 58
# -------------------------------
# loss: 0.745427  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062225
#
# Epoch 59
# -------------------------------
# loss: 0.744389  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062260
#
# Epoch 60
# -------------------------------
# loss: 0.807177  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062205
#
# Epoch 61
# -------------------------------
# loss: 0.744700  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062057
#
# Epoch 62
# -------------------------------
# loss: 0.744124  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062031
#
# Epoch 63
# -------------------------------
# loss: 0.807207  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062062
#
# Epoch 64
# -------------------------------
# loss: 0.744320  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062201
#
# Epoch 65
# -------------------------------
# loss: 0.745480  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062232
#
# Epoch 66
# -------------------------------
# loss: 0.744150  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062061
#
# Epoch 67
# -------------------------------
# loss: 0.744254  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062040
#
# Epoch 68
# -------------------------------
# loss: 0.744748  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062195
#
# Epoch 69
# -------------------------------
# loss: 0.745021  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062156
#
# Epoch 70
# -------------------------------
# loss: 0.806772  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062156
#
# Epoch 71
# -------------------------------
# loss: 0.744467  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062078
#
# Epoch 72
# -------------------------------
# loss: 0.744565  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062051
#
# Epoch 73
# -------------------------------
# loss: 0.745395  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062170
#
# Epoch 74
# -------------------------------
# loss: 0.744542  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062010
#
# Epoch 75
# -------------------------------
# loss: 0.745085  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062069
#
# Epoch 76
# -------------------------------
# loss: 0.743900  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062139
#
# Epoch 77
# -------------------------------
# loss: 0.744274  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062125
#
# Epoch 78
# -------------------------------
# loss: 0.744391  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062288
#
# Epoch 79
# -------------------------------
# loss: 0.744907  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062040
#
# Epoch 80
# -------------------------------
# loss: 0.744555  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062160
#
# Epoch 81
# -------------------------------
# loss: 0.744667  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062015
#
# Epoch 82
# -------------------------------
# loss: 0.744190  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062029
#
# Epoch 83
# -------------------------------
# loss: 0.744642  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062077
#
# Epoch 84
# -------------------------------
# loss: 0.807440  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062089
#
# Epoch 85
# -------------------------------
# loss: 0.744411  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062085
#
# Epoch 86
# -------------------------------
# loss: 0.807470  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062016
#
# Epoch 87
# -------------------------------
# loss: 0.744779  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062148
#
# Epoch 88
# -------------------------------
# loss: 0.744532  [    0/10672]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.062259
#
# Epoch 89
# -------------------------------
# loss: 0.744858  [    0/10672]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.062120
#
# Epoch 90
# -------------------------------
# loss: 0.744289  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062092
#
# Epoch 91
# -------------------------------
# loss: 0.744492  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062075
#
# Epoch 92
# -------------------------------
# loss: 0.744202  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062051
#
# Epoch 93
# -------------------------------
# loss: 0.744684  [    0/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.062200
#
# Epoch 94
# -------------------------------
# loss: 0.744862  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062049
#
# Epoch 95
# -------------------------------
# loss: 0.744621  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062075
#
# Epoch 96
# -------------------------------
# loss: 0.807574  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062174
#
# Epoch 97
# -------------------------------
# loss: 0.744177  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062179
#
# Epoch 98
# -------------------------------
# loss: 0.744026  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062031
#
# Epoch 99
# -------------------------------
# loss: 0.744667  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062051
#
# Epoch 100
# -------------------------------
# loss: 0.744268  [    0/10672]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.062191

# %%
plt.plot(loss_train, label="train")
plt.plot(loss_valid, label="valid")
plt.title("Loss")
plt.legend()
plt.show()

# %%
plt.plot(correct_train, label="train")
plt.plot(correct_valid, label="valid")
plt.title("Accuracy")
plt.legend()
plt.show()
