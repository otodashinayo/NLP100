# %%
from os import path, mkdir
import pandas as pd
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torch.optim import SGD
import matplotlib.pyplot as plt

base = "/content/drive/MyDrive/NLP100/ch08"

fp_train = "70/train.csv"
fp_valid = "70/valid.csv"
df_train = pd.read_csv(path.join(base, fp_train), index_col=0)
df_valid = pd.read_csv(path.join(base, fp_valid), index_col=0)
df_train.head()
# Out:
#                                                     TITLE  ...       299
# ID                                                         ...
# 311098  RPT-Fitch Updates EMEA Consumer ABS Rating Cri...  ... -0.043620
# 49198   Gurlitt Wants to Return Nazi-Looted Art, Suedd...  ... -0.078003
# 410578  UPDATE 1-Fairfax Financial, CEO probed over po...  ... -0.030084
# 270668  Angelina Jolie - Angelina Jolie Will Not Tight...  ...  0.098994
# 301656  Patent Officials Cancel the Washington Redskin...  ...  0.029964
#
# [5 rows x 307 columns]

# %%
X_train = torch.tensor(df_train[[str(r) for r in range(300)]].values.astype("float32"))
y_train = torch.tensor(df_train["CATEGORY"].values.astype("int"))
X_valid = torch.tensor(df_valid[[str(r) for r in range(300)]].values.astype("float32"))
y_valid = torch.tensor(df_valid["CATEGORY"].values.astype("int"))
print(X_train[:5])
print(y_train[:5])
# Out:
# tensor([[-0.0013,  0.0379, -0.0267,  ...,  0.0854,  0.0412, -0.0436],
#         [ 0.1195,  0.0482, -0.0516,  ..., -0.0930,  0.0493, -0.0780],
#         [-0.0272,  0.0079, -0.0188,  ...,  0.0608,  0.0242, -0.0301],
#         [ 0.0415,  0.0238, -0.1400,  ..., -0.0728, -0.0452,  0.0990],
#         [ 0.0851,  0.0319,  0.1310,  ..., -0.0540,  0.0016,  0.0300]])
# tensor([0, 2, 0, 2, 0])

# %%
batch_size = 16
num_workers = 2
dataset_train = [(X_i, y_i) for X_i, y_i in zip(X_train, y_train)]
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True, num_workers=num_workers)
dataset_valid = [(X_i, y_i) for X_i, y_i in zip(X_valid, y_valid)]
dataloader_valid = DataLoader(dataset_valid, batch_size=batch_size, shuffle=True, num_workers=num_workers)

# %%
class Model(nn.Module):
  def __init__(self):
    super().__init__()
    self.linear = nn.Linear(300, 4, bias=False)
    self.softmax = nn.Softmax(dim=1)

  def forward(self, x):
    y = self.linear(x)
    y = self.softmax(y)
    return y

model = Model()
print(model)
# Out:
# Model(
#   (linear): Linear(in_features=300, out_features=4, bias=False)
#   (softmax): Softmax(dim=1)
# )

# %%
learning_rate = 0.001
loss_fn = nn.CrossEntropyLoss()
optimizer = SGD(model.parameters(), lr=learning_rate)

loss_train = []
correct_train = []
loss_valid = []
correct_valid = []

for epoch in range(100):
  print(f"Epoch {epoch + 1}\n-------------------------------")
  size = len(dataloader_train.dataset)
  for batch, (X, y) in enumerate(dataloader_train):
    loss = loss_fn(model(X), y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if batch % 100 == 0:
      loss, current = loss.item(), batch * len(X)
      print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

  size = len(dataloader_train.dataset)
  loss, correct = 0, 0
  with torch.no_grad():
    for X, y in dataloader_train:
      pred = model(X)
      loss += loss_fn(pred, y).item()
      correct += (pred.argmax(1) == y).type(torch.float).sum().item()
  loss /= size
  correct /= size
  loss_train.append(loss)
  correct_train.append(correct)

  size = len(dataloader_valid.dataset)
  loss, correct = 0, 0
  with torch.no_grad():
    for X, y in dataloader_valid:
      pred = model(X)
      loss += loss_fn(pred, y).item()
      correct += (pred.argmax(1) == y).type(torch.float).sum().item()
  loss /= size
  correct /= size
  loss_valid.append(loss)
  correct_valid.append(correct)
  print(f"Test Error: \n Accuracy: {(100 * correct):>0.1f}%, Avg loss: {loss:>8f} \n")

  if not path.isdir(path.join(base, "76")):
    mkdir(path.join(base, "76"))
  torch.save({"epoch": epoch, "model": model.state_dict(), "optim": optimizer.state_dict()}, path.join(base, f"76/model_{epoch}.pth"))
# Out:
# Epoch 1
# -------------------------------
# loss: 1.381899  [    0/10672]
# loss: 1.381666  [ 1600/10672]
# loss: 1.384516  [ 3200/10672]
# loss: 1.385251  [ 4800/10672]
# loss: 1.385825  [ 6400/10672]
# loss: 1.383363  [ 8000/10672]
# loss: 1.380550  [ 9600/10672]
# Test Error:
#  Accuracy: 45.4%, Avg loss: 0.086988
#
# Epoch 2
# -------------------------------
# loss: 1.380876  [    0/10672]
# loss: 1.381993  [ 1600/10672]
# loss: 1.381409  [ 3200/10672]
# loss: 1.379454  [ 4800/10672]
# loss: 1.374430  [ 6400/10672]
# loss: 1.379630  [ 8000/10672]
# loss: 1.374223  [ 9600/10672]
# Test Error:
#  Accuracy: 56.1%, Avg loss: 0.086798
#
# Epoch 3
# -------------------------------
# loss: 1.381861  [    0/10672]
# loss: 1.375332  [ 1600/10672]
# loss: 1.378383  [ 3200/10672]
# loss: 1.374734  [ 4800/10672]
# loss: 1.374988  [ 6400/10672]
# loss: 1.378542  [ 8000/10672]
# loss: 1.377315  [ 9600/10672]
# Test Error:
#  Accuracy: 61.7%, Avg loss: 0.086610
#
# Epoch 4
# -------------------------------
# loss: 1.375960  [    0/10672]
# loss: 1.379721  [ 1600/10672]
# loss: 1.379350  [ 3200/10672]
# loss: 1.368884  [ 4800/10672]
# loss: 1.369244  [ 6400/10672]
# loss: 1.372995  [ 8000/10672]
# loss: 1.370992  [ 9600/10672]
# Test Error:
#  Accuracy: 66.3%, Avg loss: 0.086413
#
# Epoch 5
# -------------------------------
# loss: 1.376697  [    0/10672]
# loss: 1.372419  [ 1600/10672]
# loss: 1.385498  [ 3200/10672]
# loss: 1.367890  [ 4800/10672]
# loss: 1.370979  [ 6400/10672]
# loss: 1.373249  [ 8000/10672]
# loss: 1.361440  [ 9600/10672]
# Test Error:
#  Accuracy: 68.8%, Avg loss: 0.086219
#
# Epoch 6
# -------------------------------
# loss: 1.366344  [    0/10672]
# loss: 1.371135  [ 1600/10672]
# loss: 1.367230  [ 3200/10672]
# loss: 1.363244  [ 4800/10672]
# loss: 1.371426  [ 6400/10672]
# loss: 1.363428  [ 8000/10672]
# loss: 1.369234  [ 9600/10672]
# Test Error:
#  Accuracy: 70.5%, Avg loss: 0.086028
#
# Epoch 7
# -------------------------------
# loss: 1.369149  [    0/10672]
# loss: 1.364478  [ 1600/10672]
# loss: 1.380640  [ 3200/10672]
# loss: 1.357689  [ 4800/10672]
# loss: 1.359051  [ 6400/10672]
# loss: 1.371228  [ 8000/10672]
# loss: 1.367136  [ 9600/10672]
# Test Error:
#  Accuracy: 72.0%, Avg loss: 0.085822
#
# Epoch 8
# -------------------------------
# loss: 1.357570  [    0/10672]
# loss: 1.359623  [ 1600/10672]
# loss: 1.363625  [ 3200/10672]
# loss: 1.366298  [ 4800/10672]
# loss: 1.362574  [ 6400/10672]
# loss: 1.368098  [ 8000/10672]
# loss: 1.365910  [ 9600/10672]
# Test Error:
#  Accuracy: 72.9%, Avg loss: 0.085616
#
# Epoch 9
# -------------------------------
# loss: 1.369917  [    0/10672]
# loss: 1.358467  [ 1600/10672]
# loss: 1.355713  [ 3200/10672]
# loss: 1.361431  [ 4800/10672]
# loss: 1.354555  [ 6400/10672]
# loss: 1.349243  [ 8000/10672]
# loss: 1.352176  [ 9600/10672]
# Test Error:
#  Accuracy: 74.1%, Avg loss: 0.085417
#
# Epoch 10
# -------------------------------
# loss: 1.356267  [    0/10672]
# loss: 1.357136  [ 1600/10672]
# loss: 1.352909  [ 3200/10672]
# loss: 1.349827  [ 4800/10672]
# loss: 1.354395  [ 6400/10672]
# loss: 1.355018  [ 8000/10672]
# loss: 1.347555  [ 9600/10672]
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.085219
#
# Epoch 11
# -------------------------------
# loss: 1.368142  [    0/10672]
# loss: 1.343316  [ 1600/10672]
# loss: 1.361257  [ 3200/10672]
# loss: 1.358823  [ 4800/10672]
# loss: 1.367524  [ 6400/10672]
# loss: 1.351116  [ 8000/10672]
# loss: 1.358320  [ 9600/10672]
# Test Error:
#  Accuracy: 75.6%, Avg loss: 0.085005
#
# Epoch 12
# -------------------------------
# loss: 1.355559  [    0/10672]
# loss: 1.359142  [ 1600/10672]
# loss: 1.341304  [ 3200/10672]
# loss: 1.366344  [ 4800/10672]
# loss: 1.339730  [ 6400/10672]
# loss: 1.340156  [ 8000/10672]
# loss: 1.347623  [ 9600/10672]
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.084813
#
# Epoch 13
# -------------------------------
# loss: 1.341807  [    0/10672]
# loss: 1.348311  [ 1600/10672]
# loss: 1.338473  [ 3200/10672]
# loss: 1.361532  [ 4800/10672]
# loss: 1.352358  [ 6400/10672]
# loss: 1.333842  [ 8000/10672]
# loss: 1.341409  [ 9600/10672]
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.084599
#
# Epoch 14
# -------------------------------
# loss: 1.346297  [    0/10672]
# loss: 1.342265  [ 1600/10672]
# loss: 1.342441  [ 3200/10672]
# loss: 1.343431  [ 4800/10672]
# loss: 1.330955  [ 6400/10672]
# loss: 1.340251  [ 8000/10672]
# loss: 1.341154  [ 9600/10672]
# Test Error:
#  Accuracy: 76.3%, Avg loss: 0.084401
#
# Epoch 15
# -------------------------------
# loss: 1.330040  [    0/10672]
# loss: 1.339231  [ 1600/10672]
# loss: 1.343823  [ 3200/10672]
# loss: 1.336955  [ 4800/10672]
# loss: 1.329888  [ 6400/10672]
# loss: 1.332785  [ 8000/10672]
# loss: 1.349973  [ 9600/10672]
# Test Error:
#  Accuracy: 76.5%, Avg loss: 0.084180
#
# Epoch 16
# -------------------------------
# loss: 1.323806  [    0/10672]
# loss: 1.339568  [ 1600/10672]
# loss: 1.323999  [ 3200/10672]
# loss: 1.328632  [ 4800/10672]
# loss: 1.349104  [ 6400/10672]
# loss: 1.326369  [ 8000/10672]
# loss: 1.329333  [ 9600/10672]
# Test Error:
#  Accuracy: 76.7%, Avg loss: 0.083976
#
# Epoch 17
# -------------------------------
# loss: 1.341198  [    0/10672]
# loss: 1.339516  [ 1600/10672]
# loss: 1.328729  [ 3200/10672]
# loss: 1.332520  [ 4800/10672]
# loss: 1.320902  [ 6400/10672]
# loss: 1.331363  [ 8000/10672]
# loss: 1.316747  [ 9600/10672]
# Test Error:
#  Accuracy: 76.8%, Avg loss: 0.083760
#
# Epoch 18
# -------------------------------
# loss: 1.349005  [    0/10672]
# loss: 1.339571  [ 1600/10672]
# loss: 1.309608  [ 3200/10672]
# loss: 1.318224  [ 4800/10672]
# loss: 1.301345  [ 6400/10672]
# loss: 1.335458  [ 8000/10672]
# loss: 1.318106  [ 9600/10672]
# Test Error:
#  Accuracy: 76.9%, Avg loss: 0.083568
#
# Epoch 19
# -------------------------------
# loss: 1.327448  [    0/10672]
# loss: 1.326863  [ 1600/10672]
# loss: 1.340690  [ 3200/10672]
# loss: 1.312033  [ 4800/10672]
# loss: 1.315155  [ 6400/10672]
# loss: 1.325958  [ 8000/10672]
# loss: 1.329343  [ 9600/10672]
# Test Error:
#  Accuracy: 77.1%, Avg loss: 0.083323
#
# Epoch 20
# -------------------------------
# loss: 1.293561  [    0/10672]
# loss: 1.308294  [ 1600/10672]
# loss: 1.340289  [ 3200/10672]
# loss: 1.340952  [ 4800/10672]
# loss: 1.330660  [ 6400/10672]
# loss: 1.323907  [ 8000/10672]
# loss: 1.310195  [ 9600/10672]
# Test Error:
#  Accuracy: 77.3%, Avg loss: 0.083128
#
# Epoch 21
# -------------------------------
# loss: 1.332883  [    0/10672]
# loss: 1.322645  [ 1600/10672]
# loss: 1.327280  [ 3200/10672]
# loss: 1.297409  [ 4800/10672]
# loss: 1.322964  [ 6400/10672]
# loss: 1.310827  [ 8000/10672]
# loss: 1.350953  [ 9600/10672]
# Test Error:
#  Accuracy: 77.3%, Avg loss: 0.082903
#
# Epoch 22
# -------------------------------
# loss: 1.297813  [    0/10672]
# loss: 1.327255  [ 1600/10672]
# loss: 1.328120  [ 3200/10672]
# loss: 1.321331  [ 4800/10672]
# loss: 1.314257  [ 6400/10672]
# loss: 1.315044  [ 8000/10672]
# loss: 1.325930  [ 9600/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.082701
#
# Epoch 23
# -------------------------------
# loss: 1.309700  [    0/10672]
# loss: 1.290386  [ 1600/10672]
# loss: 1.300647  [ 3200/10672]
# loss: 1.290119  [ 4800/10672]
# loss: 1.295999  [ 6400/10672]
# loss: 1.330895  [ 8000/10672]
# loss: 1.328897  [ 9600/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.082486
#
# Epoch 24
# -------------------------------
# loss: 1.308632  [    0/10672]
# loss: 1.271501  [ 1600/10672]
# loss: 1.302073  [ 3200/10672]
# loss: 1.306032  [ 4800/10672]
# loss: 1.281347  [ 6400/10672]
# loss: 1.316040  [ 8000/10672]
# loss: 1.275559  [ 9600/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.082265
#
# Epoch 25
# -------------------------------
# loss: 1.294831  [    0/10672]
# loss: 1.304309  [ 1600/10672]
# loss: 1.329401  [ 3200/10672]
# loss: 1.305722  [ 4800/10672]
# loss: 1.327612  [ 6400/10672]
# loss: 1.271216  [ 8000/10672]
# loss: 1.249005  [ 9600/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.082066
#
# Epoch 26
# -------------------------------
# loss: 1.299831  [    0/10672]
# loss: 1.298789  [ 1600/10672]
# loss: 1.324180  [ 3200/10672]
# loss: 1.288618  [ 4800/10672]
# loss: 1.293087  [ 6400/10672]
# loss: 1.293238  [ 8000/10672]
# loss: 1.340358  [ 9600/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.081832
#
# Epoch 27
# -------------------------------
# loss: 1.284417  [    0/10672]
# loss: 1.284014  [ 1600/10672]
# loss: 1.304850  [ 3200/10672]
# loss: 1.290861  [ 4800/10672]
# loss: 1.292542  [ 6400/10672]
# loss: 1.315405  [ 8000/10672]
# loss: 1.262572  [ 9600/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.081638
#
# Epoch 28
# -------------------------------
# loss: 1.299345  [    0/10672]
# loss: 1.265481  [ 1600/10672]
# loss: 1.304899  [ 3200/10672]
# loss: 1.339828  [ 4800/10672]
# loss: 1.289612  [ 6400/10672]
# loss: 1.264885  [ 8000/10672]
# loss: 1.302812  [ 9600/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.081445
#
# Epoch 29
# -------------------------------
# loss: 1.308366  [    0/10672]
# loss: 1.325018  [ 1600/10672]
# loss: 1.250418  [ 3200/10672]
# loss: 1.269441  [ 4800/10672]
# loss: 1.270043  [ 6400/10672]
# loss: 1.305888  [ 8000/10672]
# loss: 1.316114  [ 9600/10672]
# Test Error:
#  Accuracy: 77.6%, Avg loss: 0.081244
#
# Epoch 30
# -------------------------------
# loss: 1.317806  [    0/10672]
# loss: 1.297210  [ 1600/10672]
# loss: 1.297901  [ 3200/10672]
# loss: 1.280006  [ 4800/10672]
# loss: 1.296026  [ 6400/10672]
# loss: 1.302900  [ 8000/10672]
# loss: 1.263975  [ 9600/10672]
# Test Error:
#  Accuracy: 77.6%, Avg loss: 0.081016
#
# Epoch 31
# -------------------------------
# loss: 1.320399  [    0/10672]
# loss: 1.310349  [ 1600/10672]
# loss: 1.275321  [ 3200/10672]
# loss: 1.306335  [ 4800/10672]
# loss: 1.291413  [ 6400/10672]
# loss: 1.299344  [ 8000/10672]
# loss: 1.282396  [ 9600/10672]
# Test Error:
#  Accuracy: 77.6%, Avg loss: 0.080773
#
# Epoch 32
# -------------------------------
# loss: 1.256769  [    0/10672]
# loss: 1.297418  [ 1600/10672]
# loss: 1.265513  [ 3200/10672]
# loss: 1.338544  [ 4800/10672]
# loss: 1.249000  [ 6400/10672]
# loss: 1.305767  [ 8000/10672]
# loss: 1.258642  [ 9600/10672]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.080565
#
# Epoch 33
# -------------------------------
# loss: 1.253655  [    0/10672]
# loss: 1.266464  [ 1600/10672]
# loss: 1.273812  [ 3200/10672]
# loss: 1.310998  [ 4800/10672]
# loss: 1.270388  [ 6400/10672]
# loss: 1.298211  [ 8000/10672]
# loss: 1.289798  [ 9600/10672]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.080427
#
# Epoch 34
# -------------------------------
# loss: 1.274161  [    0/10672]
# loss: 1.278517  [ 1600/10672]
# loss: 1.290491  [ 3200/10672]
# loss: 1.310878  [ 4800/10672]
# loss: 1.238099  [ 6400/10672]
# loss: 1.277430  [ 8000/10672]
# loss: 1.310888  [ 9600/10672]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.080146
#
# Epoch 35
# -------------------------------
# loss: 1.235113  [    0/10672]
# loss: 1.233805  [ 1600/10672]
# loss: 1.301920  [ 3200/10672]
# loss: 1.265389  [ 4800/10672]
# loss: 1.215399  [ 6400/10672]
# loss: 1.300522  [ 8000/10672]
# loss: 1.376274  [ 9600/10672]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.080012
#
# Epoch 36
# -------------------------------
# loss: 1.340313  [    0/10672]
# loss: 1.259569  [ 1600/10672]
# loss: 1.286921  [ 3200/10672]
# loss: 1.250006  [ 4800/10672]
# loss: 1.309574  [ 6400/10672]
# loss: 1.292710  [ 8000/10672]
# loss: 1.319803  [ 9600/10672]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.079747
#
# Epoch 37
# -------------------------------
# loss: 1.266885  [    0/10672]
# loss: 1.283854  [ 1600/10672]
# loss: 1.236792  [ 3200/10672]
# loss: 1.238379  [ 4800/10672]
# loss: 1.295136  [ 6400/10672]
# loss: 1.307946  [ 8000/10672]
# loss: 1.343286  [ 9600/10672]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.079613
#
# Epoch 38
# -------------------------------
# loss: 1.263534  [    0/10672]
# loss: 1.267421  [ 1600/10672]
# loss: 1.251830  [ 3200/10672]
# loss: 1.265405  [ 4800/10672]
# loss: 1.260868  [ 6400/10672]
# loss: 1.280801  [ 8000/10672]
# loss: 1.260281  [ 9600/10672]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.079344
#
# Epoch 39
# -------------------------------
# loss: 1.262153  [    0/10672]
# loss: 1.264206  [ 1600/10672]
# loss: 1.295442  [ 3200/10672]
# loss: 1.235921  [ 4800/10672]
# loss: 1.219136  [ 6400/10672]
# loss: 1.297870  [ 8000/10672]
# loss: 1.219018  [ 9600/10672]
# Test Error:
#  Accuracy: 77.9%, Avg loss: 0.079204
#
# Epoch 40
# -------------------------------
# loss: 1.274438  [    0/10672]
# loss: 1.293821  [ 1600/10672]
# loss: 1.253544  [ 3200/10672]
# loss: 1.201910  [ 4800/10672]
# loss: 1.255781  [ 6400/10672]
# loss: 1.232083  [ 8000/10672]
# loss: 1.259203  [ 9600/10672]
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.078953
#
# Epoch 41
# -------------------------------
# loss: 1.287008  [    0/10672]
# loss: 1.253358  [ 1600/10672]
# loss: 1.291937  [ 3200/10672]
# loss: 1.257162  [ 4800/10672]
# loss: 1.299722  [ 6400/10672]
# loss: 1.267141  [ 8000/10672]
# loss: 1.179972  [ 9600/10672]
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.078745
#
# Epoch 42
# -------------------------------
# loss: 1.261564  [    0/10672]
# loss: 1.193648  [ 1600/10672]
# loss: 1.294752  [ 3200/10672]
# loss: 1.307070  [ 4800/10672]
# loss: 1.271737  [ 6400/10672]
# loss: 1.259590  [ 8000/10672]
# loss: 1.295766  [ 9600/10672]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.078557
#
# Epoch 43
# -------------------------------
# loss: 1.226406  [    0/10672]
# loss: 1.266473  [ 1600/10672]
# loss: 1.201479  [ 3200/10672]
# loss: 1.262017  [ 4800/10672]
# loss: 1.210418  [ 6400/10672]
# loss: 1.260743  [ 8000/10672]
# loss: 1.190902  [ 9600/10672]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.078414
#
# Epoch 44
# -------------------------------
# loss: 1.251366  [    0/10672]
# loss: 1.269531  [ 1600/10672]
# loss: 1.288876  [ 3200/10672]
# loss: 1.248164  [ 4800/10672]
# loss: 1.209883  [ 6400/10672]
# loss: 1.219444  [ 8000/10672]
# loss: 1.283327  [ 9600/10672]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.078217
#
# Epoch 45
# -------------------------------
# loss: 1.292517  [    0/10672]
# loss: 1.235969  [ 1600/10672]
# loss: 1.225230  [ 3200/10672]
# loss: 1.227893  [ 4800/10672]
# loss: 1.221171  [ 6400/10672]
# loss: 1.241315  [ 8000/10672]
# loss: 1.190870  [ 9600/10672]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.077946
#
# Epoch 46
# -------------------------------
# loss: 1.199823  [    0/10672]
# loss: 1.215367  [ 1600/10672]
# loss: 1.201927  [ 3200/10672]
# loss: 1.226521  [ 4800/10672]
# loss: 1.262042  [ 6400/10672]
# loss: 1.230549  [ 8000/10672]
# loss: 1.223610  [ 9600/10672]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.077827
#
# Epoch 47
# -------------------------------
# loss: 1.245884  [    0/10672]
# loss: 1.208861  [ 1600/10672]
# loss: 1.209678  [ 3200/10672]
# loss: 1.246794  [ 4800/10672]
# loss: 1.231841  [ 6400/10672]
# loss: 1.165586  [ 8000/10672]
# loss: 1.210482  [ 9600/10672]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.077606
#
# Epoch 48
# -------------------------------
# loss: 1.209563  [    0/10672]
# loss: 1.240211  [ 1600/10672]
# loss: 1.210386  [ 3200/10672]
# loss: 1.202832  [ 4800/10672]
# loss: 1.344163  [ 6400/10672]
# loss: 1.231942  [ 8000/10672]
# loss: 1.198213  [ 9600/10672]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.077427
#
# Epoch 49
# -------------------------------
# loss: 1.173735  [    0/10672]
# loss: 1.264315  [ 1600/10672]
# loss: 1.206328  [ 3200/10672]
# loss: 1.199143  [ 4800/10672]
# loss: 1.180768  [ 6400/10672]
# loss: 1.251166  [ 8000/10672]
# loss: 1.285538  [ 9600/10672]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.077288
#
# Epoch 50
# -------------------------------
# loss: 1.194031  [    0/10672]
# loss: 1.232611  [ 1600/10672]
# loss: 1.160594  [ 3200/10672]
# loss: 1.280897  [ 4800/10672]
# loss: 1.258936  [ 6400/10672]
# loss: 1.215285  [ 8000/10672]
# loss: 1.284184  [ 9600/10672]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.077091
#
# Epoch 51
# -------------------------------
# loss: 1.235116  [    0/10672]
# loss: 1.335543  [ 1600/10672]
# loss: 1.142850  [ 3200/10672]
# loss: 1.217300  [ 4800/10672]
# loss: 1.162968  [ 6400/10672]
# loss: 1.249018  [ 8000/10672]
# loss: 1.252971  [ 9600/10672]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.076912
#
# Epoch 52
# -------------------------------
# loss: 1.236359  [    0/10672]
# loss: 1.160942  [ 1600/10672]
# loss: 1.254422  [ 3200/10672]
# loss: 1.266842  [ 4800/10672]
# loss: 1.222618  [ 6400/10672]
# loss: 1.211596  [ 8000/10672]
# loss: 1.198451  [ 9600/10672]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.076762
#
# Epoch 53
# -------------------------------
# loss: 1.205807  [    0/10672]
# loss: 1.176117  [ 1600/10672]
# loss: 1.201477  [ 3200/10672]
# loss: 1.174678  [ 4800/10672]
# loss: 1.233470  [ 6400/10672]
# loss: 1.129362  [ 8000/10672]
# loss: 1.277838  [ 9600/10672]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.076557
#
# Epoch 54
# -------------------------------
# loss: 1.242229  [    0/10672]
# loss: 1.227890  [ 1600/10672]
# loss: 1.165793  [ 3200/10672]
# loss: 1.177541  [ 4800/10672]
# loss: 1.203953  [ 6400/10672]
# loss: 1.181249  [ 8000/10672]
# loss: 1.238078  [ 9600/10672]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.076371
#
# Epoch 55
# -------------------------------
# loss: 1.198244  [    0/10672]
# loss: 1.263244  [ 1600/10672]
# loss: 1.184965  [ 3200/10672]
# loss: 1.216662  [ 4800/10672]
# loss: 1.159421  [ 6400/10672]
# loss: 1.149294  [ 8000/10672]
# loss: 1.216298  [ 9600/10672]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.076194
#
# Epoch 56
# -------------------------------
# loss: 1.124538  [    0/10672]
# loss: 1.184135  [ 1600/10672]
# loss: 1.225863  [ 3200/10672]
# loss: 1.211904  [ 4800/10672]
# loss: 1.130031  [ 6400/10672]
# loss: 1.162578  [ 8000/10672]
# loss: 1.197951  [ 9600/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.076097
#
# Epoch 57
# -------------------------------
# loss: 1.230557  [    0/10672]
# loss: 1.202976  [ 1600/10672]
# loss: 1.123639  [ 3200/10672]
# loss: 1.279317  [ 4800/10672]
# loss: 1.210806  [ 6400/10672]
# loss: 1.247288  [ 8000/10672]
# loss: 1.220308  [ 9600/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.075833
#
# Epoch 58
# -------------------------------
# loss: 1.126193  [    0/10672]
# loss: 1.172390  [ 1600/10672]
# loss: 1.166147  [ 3200/10672]
# loss: 1.222131  [ 4800/10672]
# loss: 1.139092  [ 6400/10672]
# loss: 1.165902  [ 8000/10672]
# loss: 1.238894  [ 9600/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.075771
#
# Epoch 59
# -------------------------------
# loss: 1.236187  [    0/10672]
# loss: 1.221413  [ 1600/10672]
# loss: 1.190859  [ 3200/10672]
# loss: 1.233861  [ 4800/10672]
# loss: 1.227106  [ 6400/10672]
# loss: 1.279332  [ 8000/10672]
# loss: 1.211905  [ 9600/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.075521
#
# Epoch 60
# -------------------------------
# loss: 1.126700  [    0/10672]
# loss: 1.189829  [ 1600/10672]
# loss: 1.265382  [ 3200/10672]
# loss: 1.204486  [ 4800/10672]
# loss: 1.244982  [ 6400/10672]
# loss: 1.281982  [ 8000/10672]
# loss: 1.136957  [ 9600/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.075377
#
# Epoch 61
# -------------------------------
# loss: 1.285680  [    0/10672]
# loss: 1.151430  [ 1600/10672]
# loss: 1.230327  [ 3200/10672]
# loss: 1.201336  [ 4800/10672]
# loss: 1.199025  [ 6400/10672]
# loss: 1.201399  [ 8000/10672]
# loss: 1.168899  [ 9600/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.075228
#
# Epoch 62
# -------------------------------
# loss: 1.150548  [    0/10672]
# loss: 1.238436  [ 1600/10672]
# loss: 1.235680  [ 3200/10672]
# loss: 1.159267  [ 4800/10672]
# loss: 1.244123  [ 6400/10672]
# loss: 1.206384  [ 8000/10672]
# loss: 1.197870  [ 9600/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.075034
#
# Epoch 63
# -------------------------------
# loss: 1.265909  [    0/10672]
# loss: 1.152333  [ 1600/10672]
# loss: 1.237623  [ 3200/10672]
# loss: 1.224591  [ 4800/10672]
# loss: 1.193471  [ 6400/10672]
# loss: 1.168648  [ 8000/10672]
# loss: 1.232018  [ 9600/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.074878
#
# Epoch 64
# -------------------------------
# loss: 1.216620  [    0/10672]
# loss: 1.177937  [ 1600/10672]
# loss: 1.161184  [ 3200/10672]
# loss: 1.109392  [ 4800/10672]
# loss: 1.232791  [ 6400/10672]
# loss: 1.250548  [ 8000/10672]
# loss: 1.233651  [ 9600/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.074727
#
# Epoch 65
# -------------------------------
# loss: 1.241194  [    0/10672]
# loss: 1.219288  [ 1600/10672]
# loss: 1.252041  [ 3200/10672]
# loss: 1.205248  [ 4800/10672]
# loss: 1.208879  [ 6400/10672]
# loss: 1.164202  [ 8000/10672]
# loss: 1.235940  [ 9600/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.074623
#
# Epoch 66
# -------------------------------
# loss: 1.266458  [    0/10672]
# loss: 1.090294  [ 1600/10672]
# loss: 1.274034  [ 3200/10672]
# loss: 1.146904  [ 4800/10672]
# loss: 1.229346  [ 6400/10672]
# loss: 1.262260  [ 8000/10672]
# loss: 1.220579  [ 9600/10672]
# Test Error:
#  Accuracy: 78.4%, Avg loss: 0.074493
#
# Epoch 67
# -------------------------------
# loss: 1.173309  [    0/10672]
# loss: 1.195681  [ 1600/10672]
# loss: 1.061592  [ 3200/10672]
# loss: 1.205665  [ 4800/10672]
# loss: 1.153729  [ 6400/10672]
# loss: 1.163791  [ 8000/10672]
# loss: 1.202463  [ 9600/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.074389
#
# Epoch 68
# -------------------------------
# loss: 1.195806  [    0/10672]
# loss: 1.097758  [ 1600/10672]
# loss: 1.126076  [ 3200/10672]
# loss: 1.192957  [ 4800/10672]
# loss: 1.084675  [ 6400/10672]
# loss: 1.147073  [ 8000/10672]
# loss: 1.107440  [ 9600/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.074151
#
# Epoch 69
# -------------------------------
# loss: 1.115637  [    0/10672]
# loss: 1.119223  [ 1600/10672]
# loss: 1.220144  [ 3200/10672]
# loss: 1.128403  [ 4800/10672]
# loss: 1.234440  [ 6400/10672]
# loss: 1.193857  [ 8000/10672]
# loss: 1.211426  [ 9600/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.074037
#
# Epoch 70
# -------------------------------
# loss: 1.261952  [    0/10672]
# loss: 1.169885  [ 1600/10672]
# loss: 1.137163  [ 3200/10672]
# loss: 1.277910  [ 4800/10672]
# loss: 1.187207  [ 6400/10672]
# loss: 1.157111  [ 8000/10672]
# loss: 1.180535  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.073884
#
# Epoch 71
# -------------------------------
# loss: 1.138570  [    0/10672]
# loss: 1.305066  [ 1600/10672]
# loss: 1.136949  [ 3200/10672]
# loss: 1.163872  [ 4800/10672]
# loss: 1.142701  [ 6400/10672]
# loss: 1.199651  [ 8000/10672]
# loss: 1.184750  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.073755
#
# Epoch 72
# -------------------------------
# loss: 1.233579  [    0/10672]
# loss: 1.197928  [ 1600/10672]
# loss: 1.196995  [ 3200/10672]
# loss: 1.146362  [ 4800/10672]
# loss: 1.136856  [ 6400/10672]
# loss: 1.180965  [ 8000/10672]
# loss: 1.160592  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.073679
#
# Epoch 73
# -------------------------------
# loss: 1.158082  [    0/10672]
# loss: 1.142354  [ 1600/10672]
# loss: 1.172918  [ 3200/10672]
# loss: 1.223858  [ 4800/10672]
# loss: 1.254618  [ 6400/10672]
# loss: 1.189824  [ 8000/10672]
# loss: 1.186788  [ 9600/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.073467
#
# Epoch 74
# -------------------------------
# loss: 1.204211  [    0/10672]
# loss: 1.200445  [ 1600/10672]
# loss: 1.275924  [ 3200/10672]
# loss: 1.200039  [ 4800/10672]
# loss: 1.260692  [ 6400/10672]
# loss: 1.167283  [ 8000/10672]
# loss: 1.183544  [ 9600/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.073350
#
# Epoch 75
# -------------------------------
# loss: 1.195519  [    0/10672]
# loss: 1.101758  [ 1600/10672]
# loss: 1.215171  [ 3200/10672]
# loss: 1.272598  [ 4800/10672]
# loss: 1.204521  [ 6400/10672]
# loss: 1.233224  [ 8000/10672]
# loss: 1.126580  [ 9600/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.073205
#
# Epoch 76
# -------------------------------
# loss: 1.198798  [    0/10672]
# loss: 1.118549  [ 1600/10672]
# loss: 1.134450  [ 3200/10672]
# loss: 1.111796  [ 4800/10672]
# loss: 1.093233  [ 6400/10672]
# loss: 1.252499  [ 8000/10672]
# loss: 1.270772  [ 9600/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.073112
#
# Epoch 77
# -------------------------------
# loss: 1.196970  [    0/10672]
# loss: 1.134656  [ 1600/10672]
# loss: 1.234208  [ 3200/10672]
# loss: 1.248870  [ 4800/10672]
# loss: 1.087684  [ 6400/10672]
# loss: 1.223845  [ 8000/10672]
# loss: 1.178699  [ 9600/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.073056
#
# Epoch 78
# -------------------------------
# loss: 1.184071  [    0/10672]
# loss: 1.092989  [ 1600/10672]
# loss: 1.115975  [ 3200/10672]
# loss: 1.213454  [ 4800/10672]
# loss: 1.137792  [ 6400/10672]
# loss: 1.225800  [ 8000/10672]
# loss: 1.155180  [ 9600/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.072890
#
# Epoch 79
# -------------------------------
# loss: 1.172609  [    0/10672]
# loss: 1.139306  [ 1600/10672]
# loss: 1.091899  [ 3200/10672]
# loss: 1.082736  [ 4800/10672]
# loss: 1.146700  [ 6400/10672]
# loss: 1.194187  [ 8000/10672]
# loss: 1.202086  [ 9600/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.072760
#
# Epoch 80
# -------------------------------
# loss: 1.077486  [    0/10672]
# loss: 1.129845  [ 1600/10672]
# loss: 1.194770  [ 3200/10672]
# loss: 1.140491  [ 4800/10672]
# loss: 1.254294  [ 6400/10672]
# loss: 1.183162  [ 8000/10672]
# loss: 1.144726  [ 9600/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.072563
#
# Epoch 81
# -------------------------------
# loss: 1.138999  [    0/10672]
# loss: 1.117922  [ 1600/10672]
# loss: 1.200873  [ 3200/10672]
# loss: 1.195945  [ 4800/10672]
# loss: 1.112147  [ 6400/10672]
# loss: 1.145644  [ 8000/10672]
# loss: 1.177963  [ 9600/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.072535
#
# Epoch 82
# -------------------------------
# loss: 1.188594  [    0/10672]
# loss: 1.113559  [ 1600/10672]
# loss: 1.165824  [ 3200/10672]
# loss: 1.223998  [ 4800/10672]
# loss: 1.125491  [ 6400/10672]
# loss: 1.154021  [ 8000/10672]
# loss: 1.265766  [ 9600/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.072374
#
# Epoch 83
# -------------------------------
# loss: 1.163111  [    0/10672]
# loss: 1.179760  [ 1600/10672]
# loss: 1.085998  [ 3200/10672]
# loss: 1.212298  [ 4800/10672]
# loss: 1.178099  [ 6400/10672]
# loss: 1.072393  [ 8000/10672]
# loss: 1.212011  [ 9600/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.072339
#
# Epoch 84
# -------------------------------
# loss: 1.166495  [    0/10672]
# loss: 1.186638  [ 1600/10672]
# loss: 1.139799  [ 3200/10672]
# loss: 1.229753  [ 4800/10672]
# loss: 1.194423  [ 6400/10672]
# loss: 1.217223  [ 8000/10672]
# loss: 1.136348  [ 9600/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.072194
#
# Epoch 85
# -------------------------------
# loss: 1.199895  [    0/10672]
# loss: 1.164825  [ 1600/10672]
# loss: 1.102102  [ 3200/10672]
# loss: 1.141599  [ 4800/10672]
# loss: 1.187220  [ 6400/10672]
# loss: 1.141739  [ 8000/10672]
# loss: 1.217946  [ 9600/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.072109
#
# Epoch 86
# -------------------------------
# loss: 1.162266  [    0/10672]
# loss: 1.162359  [ 1600/10672]
# loss: 1.097758  [ 3200/10672]
# loss: 1.172127  [ 4800/10672]
# loss: 1.185056  [ 6400/10672]
# loss: 1.153379  [ 8000/10672]
# loss: 1.150467  [ 9600/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.071965
#
# Epoch 87
# -------------------------------
# loss: 1.214027  [    0/10672]
# loss: 1.145422  [ 1600/10672]
# loss: 1.082878  [ 3200/10672]
# loss: 1.166731  [ 4800/10672]
# loss: 1.153552  [ 6400/10672]
# loss: 1.182132  [ 8000/10672]
# loss: 1.062647  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.071781
#
# Epoch 88
# -------------------------------
# loss: 1.182413  [    0/10672]
# loss: 1.060230  [ 1600/10672]
# loss: 1.127751  [ 3200/10672]
# loss: 1.167448  [ 4800/10672]
# loss: 1.176694  [ 6400/10672]
# loss: 1.242221  [ 8000/10672]
# loss: 1.094059  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.071696
#
# Epoch 89
# -------------------------------
# loss: 1.171200  [    0/10672]
# loss: 1.179993  [ 1600/10672]
# loss: 1.218497  [ 3200/10672]
# loss: 1.084839  [ 4800/10672]
# loss: 1.128781  [ 6400/10672]
# loss: 1.207926  [ 8000/10672]
# loss: 1.129155  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.071576
#
# Epoch 90
# -------------------------------
# loss: 1.140891  [    0/10672]
# loss: 1.151414  [ 1600/10672]
# loss: 1.178276  [ 3200/10672]
# loss: 1.149689  [ 4800/10672]
# loss: 1.032944  [ 6400/10672]
# loss: 1.099896  [ 8000/10672]
# loss: 1.232122  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.071543
#
# Epoch 91
# -------------------------------
# loss: 1.177707  [    0/10672]
# loss: 1.157545  [ 1600/10672]
# loss: 1.254830  [ 3200/10672]
# loss: 1.074401  [ 4800/10672]
# loss: 1.120178  [ 6400/10672]
# loss: 1.036805  [ 8000/10672]
# loss: 1.162259  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.071400
#
# Epoch 92
# -------------------------------
# loss: 1.274841  [    0/10672]
# loss: 1.145214  [ 1600/10672]
# loss: 1.198021  [ 3200/10672]
# loss: 1.096239  [ 4800/10672]
# loss: 1.141770  [ 6400/10672]
# loss: 1.169210  [ 8000/10672]
# loss: 1.077436  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.071398
#
# Epoch 93
# -------------------------------
# loss: 1.040351  [    0/10672]
# loss: 1.090915  [ 1600/10672]
# loss: 1.145900  [ 3200/10672]
# loss: 0.979327  [ 4800/10672]
# loss: 1.165057  [ 6400/10672]
# loss: 1.096160  [ 8000/10672]
# loss: 1.072749  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.071259
#
# Epoch 94
# -------------------------------
# loss: 1.114764  [    0/10672]
# loss: 1.172582  [ 1600/10672]
# loss: 1.133929  [ 3200/10672]
# loss: 1.086070  [ 4800/10672]
# loss: 1.148477  [ 6400/10672]
# loss: 1.088406  [ 8000/10672]
# loss: 1.186662  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.071080
#
# Epoch 95
# -------------------------------
# loss: 1.159947  [    0/10672]
# loss: 1.180510  [ 1600/10672]
# loss: 1.161018  [ 3200/10672]
# loss: 1.187152  [ 4800/10672]
# loss: 1.035588  [ 6400/10672]
# loss: 1.115239  [ 8000/10672]
# loss: 1.149464  [ 9600/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.070953
#
# Epoch 96
# -------------------------------
# loss: 1.161909  [    0/10672]
# loss: 1.209182  [ 1600/10672]
# loss: 1.140537  [ 3200/10672]
# loss: 1.164228  [ 4800/10672]
# loss: 1.117747  [ 6400/10672]
# loss: 1.171486  [ 8000/10672]
# loss: 1.194765  [ 9600/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.071011
#
# Epoch 97
# -------------------------------
# loss: 1.110691  [    0/10672]
# loss: 1.074161  [ 1600/10672]
# loss: 1.187770  [ 3200/10672]
# loss: 1.045752  [ 4800/10672]
# loss: 1.247308  [ 6400/10672]
# loss: 1.236777  [ 8000/10672]
# loss: 1.149857  [ 9600/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.070894
#
# Epoch 98
# -------------------------------
# loss: 1.186078  [    0/10672]
# loss: 1.077341  [ 1600/10672]
# loss: 1.120874  [ 3200/10672]
# loss: 1.173385  [ 4800/10672]
# loss: 1.122269  [ 6400/10672]
# loss: 1.160391  [ 8000/10672]
# loss: 1.199740  [ 9600/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.070759
#
# Epoch 99
# -------------------------------
# loss: 1.207380  [    0/10672]
# loss: 1.140879  [ 1600/10672]
# loss: 1.102272  [ 3200/10672]
# loss: 1.119562  [ 4800/10672]
# loss: 1.101546  [ 6400/10672]
# loss: 1.115051  [ 8000/10672]
# loss: 1.166496  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.070572
#
# Epoch 100
# -------------------------------
# loss: 1.128141  [    0/10672]
# loss: 1.167542  [ 1600/10672]
# loss: 1.250365  [ 3200/10672]
# loss: 1.070181  [ 4800/10672]
# loss: 1.134691  [ 6400/10672]
# loss: 1.121036  [ 8000/10672]
# loss: 1.093339  [ 9600/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.070573

# %%
plt.plot(loss_train, label="train")
plt.plot(loss_valid, label="valid")
plt.title("Loss")
plt.legend()
plt.show()

# %%
plt.plot(correct_train, label="train")
plt.plot(correct_valid, label="valid")
plt.title("Accuracy")
plt.legend()
plt.show()
