# %%
from os import path, mkdir
import pandas as pd
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torch.optim import SGD
from torch.optim.lr_scheduler import ExponentialLR
import matplotlib.pyplot as plt

base = "/content/drive/MyDrive/NLP100/ch08"

fp_train = "70/train.csv"
fp_valid = "70/valid.csv"
df_train = pd.read_csv(path.join(base, fp_train), index_col=0)
df_valid = pd.read_csv(path.join(base, fp_valid), index_col=0)
df_train.head()
# Out:
#                                                     TITLE  ...       299
# ID                                                         ...
# 311098  RPT-Fitch Updates EMEA Consumer ABS Rating Cri...  ... -0.043620
# 49198   Gurlitt Wants to Return Nazi-Looted Art, Suedd...  ... -0.078003
# 410578  UPDATE 1-Fairfax Financial, CEO probed over po...  ... -0.030084
# 270668  Angelina Jolie - Angelina Jolie Will Not Tight...  ...  0.098994
# 301656  Patent Officials Cancel the Washington Redskin...  ...  0.029964
#
# [5 rows x 307 columns]

# %%
X_train = torch.tensor(df_train[[str(r) for r in range(300)]].values.astype("float32"))
y_train = torch.tensor(df_train["CATEGORY"].values.astype("int"))
X_valid = torch.tensor(df_valid[[str(r) for r in range(300)]].values.astype("float32"))
y_valid = torch.tensor(df_valid["CATEGORY"].values.astype("int"))
print(X_train[:5])
print(y_train[:5])
# Out:
# tensor([[-0.0013,  0.0379, -0.0267,  ...,  0.0854,  0.0412, -0.0436],
#         [ 0.1195,  0.0482, -0.0516,  ..., -0.0930,  0.0493, -0.0780],
#         [-0.0272,  0.0079, -0.0188,  ...,  0.0608,  0.0242, -0.0301],
#         [ 0.0415,  0.0238, -0.1400,  ..., -0.0728, -0.0452,  0.0990],
#         [ 0.0851,  0.0319,  0.1310,  ..., -0.0540,  0.0016,  0.0300]])
# tensor([0, 2, 0, 2, 0])

# %%
batch_size = 16
num_workers = 2
dataset_train = [(X_i, y_i) for X_i, y_i in zip(X_train, y_train)]
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True, num_workers=num_workers)
dataset_valid = [(X_i, y_i) for X_i, y_i in zip(X_valid, y_valid)]
dataloader_valid = DataLoader(dataset_valid, batch_size=batch_size, shuffle=True, num_workers=num_workers)

# %%
class Model(nn.Module):
  def __init__(self):
    super().__init__()
    self.linear_1 = nn.Linear(300, 100)
    self.linear_2 = nn.Linear(100, 10)
    self.linear_3 = nn.Linear(10, 4)
    self.relu = nn.ReLU()
    self.softmax = nn.Softmax(dim=1)

  def forward(self, x):
    y = self.linear_1(x)
    y = self.relu(y)
    y = self.linear_2(y)
    y = self.relu(y)
    y = self.linear_3(y)
    y = self.softmax(y)
    return y

if torch.cuda.is_available():
  device = "cuda"
else:
  device = "cpu"
print(f"device: {device}")
model = Model().to(device)
print(model)
# Out:
# device: cuda
# Model(
#   (linear_1): Linear(in_features=300, out_features=100, bias=True)
#   (linear_2): Linear(in_features=100, out_features=10, bias=True)
#   (linear_3): Linear(in_features=10, out_features=4, bias=True)
#   (relu): ReLU()
#   (softmax): Softmax(dim=1)
# )

# %%
learning_rate = 0.1
loss_fn = nn.CrossEntropyLoss()
optimizer = SGD(model.parameters(), lr=learning_rate)
scheduler = ExponentialLR(optimizer, gamma=0.95)

loss_train = []
correct_train = []
loss_valid = []
correct_valid = []

for epoch in range(100):
  print(f"Epoch {epoch + 1}\n-------------------------------")
  size = len(dataloader_train.dataset)
  for batch, (X, y) in enumerate(dataloader_train):
    X, y = X.to(device), y.to(device)
    loss = loss_fn(model(X), y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if batch % 100 == 0:
      loss, current = loss.item(), batch * len(X)
      print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
  scheduler.step()

  size = len(dataloader_train.dataset)
  loss, correct = 0, 0
  with torch.no_grad():
    for X, y in dataloader_train:
      X, y = X.to(device), y.to(device)
      pred = model(X)
      loss += loss_fn(pred, y).item()
      correct += (pred.argmax(1) == y).type(torch.float).sum().item()
  loss /= size
  correct /= size
  loss_train.append(loss)
  correct_train.append(correct)

  size = len(dataloader_valid.dataset)
  loss, correct = 0, 0
  with torch.no_grad():
    for X, y in dataloader_valid:
      X, y = X.to(device), y.to(device)
      pred = model(X)
      loss += loss_fn(pred, y).item()
      correct += (pred.argmax(1) == y).type(torch.float).sum().item()
  loss /= size
  correct /= size
  loss_valid.append(loss)
  correct_valid.append(correct)
  print(f"Test Error: \n Accuracy: {(100 * correct):>0.1f}%, Avg loss: {loss:>8f} \n")

if not path.isdir(path.join(base, "79")):
  mkdir(path.join(base, "79"))
torch.save(model.state_dict(), path.join(base, "79/model.pth"))
# Out:
# Epoch 1
# -------------------------------
# loss: 1.378133  [    0/10672]
# loss: 1.292964  [ 1600/10672]
# loss: 1.220829  [ 3200/10672]
# loss: 1.208368  [ 4800/10672]
# loss: 1.226937  [ 6400/10672]
# loss: 1.118908  [ 8000/10672]
# loss: 1.046692  [ 9600/10672]
# Test Error:
#  Accuracy: 79.2%, Avg loss: 0.061272
#
# Epoch 2
# -------------------------------
# loss: 1.008385  [    0/10672]
# loss: 1.024122  [ 1600/10672]
# loss: 0.872953  [ 3200/10672]
# loss: 0.868662  [ 4800/10672]
# loss: 1.051967  [ 6400/10672]
# loss: 0.884029  [ 8000/10672]
# loss: 0.811347  [ 9600/10672]
# Test Error:
#  Accuracy: 79.5%, Avg loss: 0.059836
#
# Epoch 3
# -------------------------------
# loss: 0.861431  [    0/10672]
# loss: 0.754432  [ 1600/10672]
# loss: 0.969186  [ 3200/10672]
# loss: 0.991839  [ 4800/10672]
# loss: 0.900432  [ 6400/10672]
# loss: 0.994176  [ 8000/10672]
# loss: 0.941156  [ 9600/10672]
# Test Error:
#  Accuracy: 79.5%, Avg loss: 0.059797
#
# Epoch 4
# -------------------------------
# loss: 1.025375  [    0/10672]
# loss: 1.051473  [ 1600/10672]
# loss: 1.049439  [ 3200/10672]
# loss: 0.880636  [ 4800/10672]
# loss: 0.808168  [ 6400/10672]
# loss: 1.060309  [ 8000/10672]
# loss: 0.858756  [ 9600/10672]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.059628
#
# Epoch 5
# -------------------------------
# loss: 0.989960  [    0/10672]
# loss: 1.041687  [ 1600/10672]
# loss: 0.931086  [ 3200/10672]
# loss: 0.871127  [ 4800/10672]
# loss: 0.871953  [ 6400/10672]
# loss: 0.879903  [ 8000/10672]
# loss: 0.745482  [ 9600/10672]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.059528
#
# Epoch 6
# -------------------------------
# loss: 0.930992  [    0/10672]
# loss: 0.990350  [ 1600/10672]
# loss: 0.806723  [ 3200/10672]
# loss: 0.818454  [ 4800/10672]
# loss: 0.932114  [ 6400/10672]
# loss: 1.050168  [ 8000/10672]
# loss: 0.752212  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059523
#
# Epoch 7
# -------------------------------
# loss: 0.853705  [    0/10672]
# loss: 1.151559  [ 1600/10672]
# loss: 1.117447  [ 3200/10672]
# loss: 0.931193  [ 4800/10672]
# loss: 0.929400  [ 6400/10672]
# loss: 1.047366  [ 8000/10672]
# loss: 0.930868  [ 9600/10672]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.059550
#
# Epoch 8
# -------------------------------
# loss: 0.930814  [    0/10672]
# loss: 1.173996  [ 1600/10672]
# loss: 1.019615  [ 3200/10672]
# loss: 0.936253  [ 4800/10672]
# loss: 0.990128  [ 6400/10672]
# loss: 0.824446  [ 8000/10672]
# loss: 1.049575  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059624
#
# Epoch 9
# -------------------------------
# loss: 1.055776  [    0/10672]
# loss: 0.930695  [ 1600/10672]
# loss: 0.883368  [ 3200/10672]
# loss: 1.231227  [ 4800/10672]
# loss: 1.059055  [ 6400/10672]
# loss: 0.929604  [ 8000/10672]
# loss: 0.974401  [ 9600/10672]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.059388
#
# Epoch 10
# -------------------------------
# loss: 0.880665  [    0/10672]
# loss: 0.993188  [ 1600/10672]
# loss: 0.822208  [ 3200/10672]
# loss: 0.933083  [ 4800/10672]
# loss: 1.068296  [ 6400/10672]
# loss: 0.868929  [ 8000/10672]
# loss: 0.959887  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059439
#
# Epoch 11
# -------------------------------
# loss: 1.000591  [    0/10672]
# loss: 0.868853  [ 1600/10672]
# loss: 0.744102  [ 3200/10672]
# loss: 0.745277  [ 4800/10672]
# loss: 0.865164  [ 6400/10672]
# loss: 0.940654  [ 8000/10672]
# loss: 0.871334  [ 9600/10672]
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.059565
#
# Epoch 12
# -------------------------------
# loss: 0.935282  [    0/10672]
# loss: 0.863127  [ 1600/10672]
# loss: 1.114328  [ 3200/10672]
# loss: 1.001517  [ 4800/10672]
# loss: 0.994332  [ 6400/10672]
# loss: 0.986233  [ 8000/10672]
# loss: 0.818917  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059363
#
# Epoch 13
# -------------------------------
# loss: 0.907953  [    0/10672]
# loss: 0.930340  [ 1600/10672]
# loss: 0.885983  [ 3200/10672]
# loss: 0.931673  [ 4800/10672]
# loss: 0.935430  [ 6400/10672]
# loss: 1.010648  [ 8000/10672]
# loss: 0.950829  [ 9600/10672]
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.059654
#
# Epoch 14
# -------------------------------
# loss: 0.945889  [    0/10672]
# loss: 0.808504  [ 1600/10672]
# loss: 0.951767  [ 3200/10672]
# loss: 0.806270  [ 4800/10672]
# loss: 0.910055  [ 6400/10672]
# loss: 1.050462  [ 8000/10672]
# loss: 1.235518  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059358
#
# Epoch 15
# -------------------------------
# loss: 1.138481  [    0/10672]
# loss: 1.055882  [ 1600/10672]
# loss: 0.994849  [ 3200/10672]
# loss: 0.940464  [ 4800/10672]
# loss: 1.124011  [ 6400/10672]
# loss: 0.991979  [ 8000/10672]
# loss: 0.983733  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059436
#
# Epoch 16
# -------------------------------
# loss: 0.743754  [    0/10672]
# loss: 1.031829  [ 1600/10672]
# loss: 0.931759  [ 3200/10672]
# loss: 0.876043  [ 4800/10672]
# loss: 0.927218  [ 6400/10672]
# loss: 0.988620  [ 8000/10672]
# loss: 1.109142  [ 9600/10672]
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.059564
#
# Epoch 17
# -------------------------------
# loss: 0.940730  [    0/10672]
# loss: 1.148404  [ 1600/10672]
# loss: 0.808335  [ 3200/10672]
# loss: 0.814293  [ 4800/10672]
# loss: 0.924360  [ 6400/10672]
# loss: 1.051561  [ 8000/10672]
# loss: 0.934069  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059581
#
# Epoch 18
# -------------------------------
# loss: 0.903538  [    0/10672]
# loss: 0.887019  [ 1600/10672]
# loss: 0.875149  [ 3200/10672]
# loss: 0.931611  [ 4800/10672]
# loss: 0.997124  [ 6400/10672]
# loss: 0.988892  [ 8000/10672]
# loss: 0.824466  [ 9600/10672]
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.059600
#
# Epoch 19
# -------------------------------
# loss: 0.932346  [    0/10672]
# loss: 0.818415  [ 1600/10672]
# loss: 1.058271  [ 3200/10672]
# loss: 1.110790  [ 4800/10672]
# loss: 0.995214  [ 6400/10672]
# loss: 0.927874  [ 8000/10672]
# loss: 0.897420  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059342
#
# Epoch 20
# -------------------------------
# loss: 0.995108  [    0/10672]
# loss: 1.054839  [ 1600/10672]
# loss: 0.829259  [ 3200/10672]
# loss: 0.875684  [ 4800/10672]
# loss: 1.052080  [ 6400/10672]
# loss: 0.993210  [ 8000/10672]
# loss: 0.816350  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059380
#
# Epoch 21
# -------------------------------
# loss: 1.117942  [    0/10672]
# loss: 0.926428  [ 1600/10672]
# loss: 0.871698  [ 3200/10672]
# loss: 0.936805  [ 4800/10672]
# loss: 0.984837  [ 6400/10672]
# loss: 0.935214  [ 8000/10672]
# loss: 0.760528  [ 9600/10672]
# Test Error:
#  Accuracy: 79.9%, Avg loss: 0.059432
#
# Epoch 22
# -------------------------------
# loss: 0.928371  [    0/10672]
# loss: 1.111623  [ 1600/10672]
# loss: 0.868844  [ 3200/10672]
# loss: 0.946347  [ 4800/10672]
# loss: 0.808497  [ 6400/10672]
# loss: 0.876419  [ 8000/10672]
# loss: 1.008831  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059430
#
# Epoch 23
# -------------------------------
# loss: 0.988370  [    0/10672]
# loss: 1.110341  [ 1600/10672]
# loss: 0.993731  [ 3200/10672]
# loss: 1.164063  [ 4800/10672]
# loss: 0.802349  [ 6400/10672]
# loss: 0.870120  [ 8000/10672]
# loss: 0.995009  [ 9600/10672]
# Test Error:
#  Accuracy: 79.9%, Avg loss: 0.059508
#
# Epoch 24
# -------------------------------
# loss: 0.853307  [    0/10672]
# loss: 1.055275  [ 1600/10672]
# loss: 0.994662  [ 3200/10672]
# loss: 0.930970  [ 4800/10672]
# loss: 0.868244  [ 6400/10672]
# loss: 1.029135  [ 8000/10672]
# loss: 0.932454  [ 9600/10672]
# Test Error:
#  Accuracy: 79.9%, Avg loss: 0.059351
#
# Epoch 25
# -------------------------------
# loss: 0.985195  [    0/10672]
# loss: 1.053970  [ 1600/10672]
# loss: 1.078478  [ 3200/10672]
# loss: 0.925371  [ 4800/10672]
# loss: 0.926254  [ 6400/10672]
# loss: 0.875223  [ 8000/10672]
# loss: 0.868494  [ 9600/10672]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.059340
#
# Epoch 26
# -------------------------------
# loss: 0.847103  [    0/10672]
# loss: 0.882400  [ 1600/10672]
# loss: 1.053415  [ 3200/10672]
# loss: 0.931680  [ 4800/10672]
# loss: 0.983281  [ 6400/10672]
# loss: 0.869393  [ 8000/10672]
# loss: 0.866489  [ 9600/10672]
# Test Error:
#  Accuracy: 79.9%, Avg loss: 0.059356
#
# Epoch 27
# -------------------------------
# loss: 1.046772  [    0/10672]
# loss: 0.932869  [ 1600/10672]
# loss: 0.934264  [ 3200/10672]
# loss: 0.929831  [ 4800/10672]
# loss: 1.038351  [ 6400/10672]
# loss: 0.868665  [ 8000/10672]
# loss: 0.995005  [ 9600/10672]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.059424
#
# Epoch 28
# -------------------------------
# loss: 0.870114  [    0/10672]
# loss: 0.763047  [ 1600/10672]
# loss: 0.868352  [ 3200/10672]
# loss: 0.992593  [ 4800/10672]
# loss: 0.990477  [ 6400/10672]
# loss: 1.139635  [ 8000/10672]
# loss: 0.870460  [ 9600/10672]
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.059485
#
# Epoch 29
# -------------------------------
# loss: 0.999106  [    0/10672]
# loss: 1.003212  [ 1600/10672]
# loss: 1.009568  [ 3200/10672]
# loss: 0.924493  [ 4800/10672]
# loss: 0.928562  [ 6400/10672]
# loss: 1.047476  [ 8000/10672]
# loss: 0.870839  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059464
#
# Epoch 30
# -------------------------------
# loss: 0.927591  [    0/10672]
# loss: 0.875651  [ 1600/10672]
# loss: 0.809942  [ 3200/10672]
# loss: 0.938687  [ 4800/10672]
# loss: 0.905066  [ 6400/10672]
# loss: 0.806930  [ 8000/10672]
# loss: 0.925803  [ 9600/10672]
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.059339
#
# Epoch 31
# -------------------------------
# loss: 0.986360  [    0/10672]
# loss: 0.867086  [ 1600/10672]
# loss: 0.999045  [ 3200/10672]
# loss: 1.185901  [ 4800/10672]
# loss: 0.946288  [ 6400/10672]
# loss: 0.806052  [ 8000/10672]
# loss: 0.876949  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059430
#
# Epoch 32
# -------------------------------
# loss: 1.051009  [    0/10672]
# loss: 0.941679  [ 1600/10672]
# loss: 0.890802  [ 3200/10672]
# loss: 0.868556  [ 4800/10672]
# loss: 0.984742  [ 6400/10672]
# loss: 0.918656  [ 8000/10672]
# loss: 1.051919  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059469
#
# Epoch 33
# -------------------------------
# loss: 1.175599  [    0/10672]
# loss: 1.053897  [ 1600/10672]
# loss: 1.009291  [ 3200/10672]
# loss: 0.869589  [ 4800/10672]
# loss: 0.869362  [ 6400/10672]
# loss: 0.942940  [ 8000/10672]
# loss: 0.930807  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059468
#
# Epoch 34
# -------------------------------
# loss: 0.870192  [    0/10672]
# loss: 0.935202  [ 1600/10672]
# loss: 0.805946  [ 3200/10672]
# loss: 1.188102  [ 4800/10672]
# loss: 0.872889  [ 6400/10672]
# loss: 0.813097  [ 8000/10672]
# loss: 0.875285  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059502
#
# Epoch 35
# -------------------------------
# loss: 0.867262  [    0/10672]
# loss: 0.820198  [ 1600/10672]
# loss: 0.873380  [ 3200/10672]
# loss: 0.921611  [ 4800/10672]
# loss: 0.806767  [ 6400/10672]
# loss: 0.935772  [ 8000/10672]
# loss: 0.821697  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059497
#
# Epoch 36
# -------------------------------
# loss: 0.993400  [    0/10672]
# loss: 0.935421  [ 1600/10672]
# loss: 0.977444  [ 3200/10672]
# loss: 0.882708  [ 4800/10672]
# loss: 0.928719  [ 6400/10672]
# loss: 0.812771  [ 8000/10672]
# loss: 0.811033  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059435
#
# Epoch 37
# -------------------------------
# loss: 0.949281  [    0/10672]
# loss: 0.865126  [ 1600/10672]
# loss: 0.927603  [ 3200/10672]
# loss: 0.868699  [ 4800/10672]
# loss: 1.010813  [ 6400/10672]
# loss: 1.054565  [ 8000/10672]
# loss: 1.059093  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059416
#
# Epoch 38
# -------------------------------
# loss: 0.992203  [    0/10672]
# loss: 0.926118  [ 1600/10672]
# loss: 0.874556  [ 3200/10672]
# loss: 0.979309  [ 4800/10672]
# loss: 1.056351  [ 6400/10672]
# loss: 0.744956  [ 8000/10672]
# loss: 0.926158  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059509
#
# Epoch 39
# -------------------------------
# loss: 0.878082  [    0/10672]
# loss: 0.868421  [ 1600/10672]
# loss: 0.926353  [ 3200/10672]
# loss: 1.051711  [ 4800/10672]
# loss: 0.857891  [ 6400/10672]
# loss: 0.928732  [ 8000/10672]
# loss: 0.868577  [ 9600/10672]
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.059344
#
# Epoch 40
# -------------------------------
# loss: 0.924922  [    0/10672]
# loss: 0.930311  [ 1600/10672]
# loss: 0.876872  [ 3200/10672]
# loss: 0.989316  [ 4800/10672]
# loss: 0.988056  [ 6400/10672]
# loss: 0.995328  [ 8000/10672]
# loss: 0.750647  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059438
#
# Epoch 41
# -------------------------------
# loss: 0.988766  [    0/10672]
# loss: 1.056752  [ 1600/10672]
# loss: 0.858647  [ 3200/10672]
# loss: 0.995901  [ 4800/10672]
# loss: 0.929981  [ 6400/10672]
# loss: 0.990774  [ 8000/10672]
# loss: 0.864209  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059468
#
# Epoch 42
# -------------------------------
# loss: 0.745414  [    0/10672]
# loss: 0.924760  [ 1600/10672]
# loss: 0.873442  [ 3200/10672]
# loss: 1.034470  [ 4800/10672]
# loss: 0.993408  [ 6400/10672]
# loss: 0.862359  [ 8000/10672]
# loss: 0.805260  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059448
#
# Epoch 43
# -------------------------------
# loss: 1.020203  [    0/10672]
# loss: 1.057621  [ 1600/10672]
# loss: 0.992656  [ 3200/10672]
# loss: 0.923128  [ 4800/10672]
# loss: 0.992014  [ 6400/10672]
# loss: 1.050840  [ 8000/10672]
# loss: 0.921729  [ 9600/10672]
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.059438
#
# Epoch 44
# -------------------------------
# loss: 0.986221  [    0/10672]
# loss: 0.993416  [ 1600/10672]
# loss: 0.806423  [ 3200/10672]
# loss: 0.806200  [ 4800/10672]
# loss: 0.932258  [ 6400/10672]
# loss: 0.955968  [ 8000/10672]
# loss: 1.184435  [ 9600/10672]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.059580
#
# Epoch 45
# -------------------------------
# loss: 0.993529  [    0/10672]
# loss: 0.929235  [ 1600/10672]
# loss: 0.744473  [ 3200/10672]
# loss: 0.750775  [ 4800/10672]
# loss: 0.936182  [ 6400/10672]
# loss: 1.105010  [ 8000/10672]
# loss: 0.928034  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059452
#
# Epoch 46
# -------------------------------
# loss: 0.867447  [    0/10672]
# loss: 0.869662  [ 1600/10672]
# loss: 0.871963  [ 3200/10672]
# loss: 0.865189  [ 4800/10672]
# loss: 0.884451  [ 6400/10672]
# loss: 0.868870  [ 8000/10672]
# loss: 1.044564  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059369
#
# Epoch 47
# -------------------------------
# loss: 1.004859  [    0/10672]
# loss: 0.932388  [ 1600/10672]
# loss: 0.930784  [ 3200/10672]
# loss: 1.233105  [ 4800/10672]
# loss: 0.806682  [ 6400/10672]
# loss: 0.926298  [ 8000/10672]
# loss: 1.055252  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059536
#
# Epoch 48
# -------------------------------
# loss: 1.050290  [    0/10672]
# loss: 0.948792  [ 1600/10672]
# loss: 1.056108  [ 3200/10672]
# loss: 1.056272  [ 4800/10672]
# loss: 0.861789  [ 6400/10672]
# loss: 0.875366  [ 8000/10672]
# loss: 0.995910  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059478
#
# Epoch 49
# -------------------------------
# loss: 1.056111  [    0/10672]
# loss: 0.992128  [ 1600/10672]
# loss: 0.984416  [ 3200/10672]
# loss: 0.871997  [ 4800/10672]
# loss: 1.042803  [ 6400/10672]
# loss: 1.052491  [ 8000/10672]
# loss: 0.987736  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059461
#
# Epoch 50
# -------------------------------
# loss: 0.868455  [    0/10672]
# loss: 0.874263  [ 1600/10672]
# loss: 0.993450  [ 3200/10672]
# loss: 0.988925  [ 4800/10672]
# loss: 0.994475  [ 6400/10672]
# loss: 0.926280  [ 8000/10672]
# loss: 0.988381  [ 9600/10672]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.059364
#
# Epoch 51
# -------------------------------
# loss: 0.876799  [    0/10672]
# loss: 0.870175  [ 1600/10672]
# loss: 0.991887  [ 3200/10672]
# loss: 0.929812  [ 4800/10672]
# loss: 0.808109  [ 6400/10672]
# loss: 0.990376  [ 8000/10672]
# loss: 0.931155  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059454
#
# Epoch 52
# -------------------------------
# loss: 0.927549  [    0/10672]
# loss: 1.062977  [ 1600/10672]
# loss: 0.932022  [ 3200/10672]
# loss: 1.201574  [ 4800/10672]
# loss: 0.871134  [ 6400/10672]
# loss: 1.005206  [ 8000/10672]
# loss: 0.935714  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059611
#
# Epoch 53
# -------------------------------
# loss: 0.811440  [    0/10672]
# loss: 0.933375  [ 1600/10672]
# loss: 0.972835  [ 3200/10672]
# loss: 0.863492  [ 4800/10672]
# loss: 0.801026  [ 6400/10672]
# loss: 0.993273  [ 8000/10672]
# loss: 0.931562  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059442
#
# Epoch 54
# -------------------------------
# loss: 0.745332  [    0/10672]
# loss: 0.816640  [ 1600/10672]
# loss: 0.983509  [ 3200/10672]
# loss: 0.932996  [ 4800/10672]
# loss: 0.867622  [ 6400/10672]
# loss: 0.926159  [ 8000/10672]
# loss: 1.106551  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059433
#
# Epoch 55
# -------------------------------
# loss: 0.993890  [    0/10672]
# loss: 1.180073  [ 1600/10672]
# loss: 0.930257  [ 3200/10672]
# loss: 1.055015  [ 4800/10672]
# loss: 0.995633  [ 6400/10672]
# loss: 0.806487  [ 8000/10672]
# loss: 0.815833  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059456
#
# Epoch 56
# -------------------------------
# loss: 0.930508  [    0/10672]
# loss: 0.930977  [ 1600/10672]
# loss: 0.897156  [ 3200/10672]
# loss: 0.923682  [ 4800/10672]
# loss: 1.045429  [ 6400/10672]
# loss: 0.986752  [ 8000/10672]
# loss: 0.994180  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059479
#
# Epoch 57
# -------------------------------
# loss: 0.941655  [    0/10672]
# loss: 0.926229  [ 1600/10672]
# loss: 0.753261  [ 3200/10672]
# loss: 1.183804  [ 4800/10672]
# loss: 0.860518  [ 6400/10672]
# loss: 0.987414  [ 8000/10672]
# loss: 1.052101  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059588
#
# Epoch 58
# -------------------------------
# loss: 0.929872  [    0/10672]
# loss: 0.973217  [ 1600/10672]
# loss: 0.889989  [ 3200/10672]
# loss: 0.989402  [ 4800/10672]
# loss: 0.748204  [ 6400/10672]
# loss: 0.931809  [ 8000/10672]
# loss: 0.932877  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059440
#
# Epoch 59
# -------------------------------
# loss: 0.994880  [    0/10672]
# loss: 0.994223  [ 1600/10672]
# loss: 0.988306  [ 3200/10672]
# loss: 0.873786  [ 4800/10672]
# loss: 0.930315  [ 6400/10672]
# loss: 0.872242  [ 8000/10672]
# loss: 1.054616  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059443
#
# Epoch 60
# -------------------------------
# loss: 0.931128  [    0/10672]
# loss: 0.812137  [ 1600/10672]
# loss: 0.987886  [ 3200/10672]
# loss: 0.925640  [ 4800/10672]
# loss: 0.985199  [ 6400/10672]
# loss: 1.113977  [ 8000/10672]
# loss: 1.050668  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059502
#
# Epoch 61
# -------------------------------
# loss: 0.935484  [    0/10672]
# loss: 1.050294  [ 1600/10672]
# loss: 1.115306  [ 3200/10672]
# loss: 1.052130  [ 4800/10672]
# loss: 0.868554  [ 6400/10672]
# loss: 0.869177  [ 8000/10672]
# loss: 0.806424  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059511
#
# Epoch 62
# -------------------------------
# loss: 1.050716  [    0/10672]
# loss: 0.925856  [ 1600/10672]
# loss: 0.802555  [ 3200/10672]
# loss: 0.990748  [ 4800/10672]
# loss: 0.930909  [ 6400/10672]
# loss: 0.875573  [ 8000/10672]
# loss: 0.743856  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059364
#
# Epoch 63
# -------------------------------
# loss: 0.807059  [    0/10672]
# loss: 0.876205  [ 1600/10672]
# loss: 0.874037  [ 3200/10672]
# loss: 0.929106  [ 4800/10672]
# loss: 0.864206  [ 6400/10672]
# loss: 0.847494  [ 8000/10672]
# loss: 1.031066  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059374
#
# Epoch 64
# -------------------------------
# loss: 0.806287  [    0/10672]
# loss: 0.765302  [ 1600/10672]
# loss: 0.806021  [ 3200/10672]
# loss: 0.931732  [ 4800/10672]
# loss: 0.880679  [ 6400/10672]
# loss: 0.868752  [ 8000/10672]
# loss: 0.926191  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059464
#
# Epoch 65
# -------------------------------
# loss: 1.052128  [    0/10672]
# loss: 0.948639  [ 1600/10672]
# loss: 0.995455  [ 3200/10672]
# loss: 1.051593  [ 4800/10672]
# loss: 0.932722  [ 6400/10672]
# loss: 0.938685  [ 8000/10672]
# loss: 1.048407  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059436
#
# Epoch 66
# -------------------------------
# loss: 0.952444  [    0/10672]
# loss: 0.927884  [ 1600/10672]
# loss: 0.927633  [ 3200/10672]
# loss: 0.994830  [ 4800/10672]
# loss: 0.922418  [ 6400/10672]
# loss: 0.927309  [ 8000/10672]
# loss: 0.867298  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059471
#
# Epoch 67
# -------------------------------
# loss: 0.930840  [    0/10672]
# loss: 0.933968  [ 1600/10672]
# loss: 0.929363  [ 3200/10672]
# loss: 0.871486  [ 4800/10672]
# loss: 1.045932  [ 6400/10672]
# loss: 0.933580  [ 8000/10672]
# loss: 0.874946  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059444
#
# Epoch 68
# -------------------------------
# loss: 0.864056  [    0/10672]
# loss: 0.871741  [ 1600/10672]
# loss: 0.806331  [ 3200/10672]
# loss: 0.870252  [ 4800/10672]
# loss: 0.931133  [ 6400/10672]
# loss: 1.046476  [ 8000/10672]
# loss: 0.931225  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059614
#
# Epoch 69
# -------------------------------
# loss: 0.929612  [    0/10672]
# loss: 1.142654  [ 1600/10672]
# loss: 0.903792  [ 3200/10672]
# loss: 0.808403  [ 4800/10672]
# loss: 0.991930  [ 6400/10672]
# loss: 1.115227  [ 8000/10672]
# loss: 1.112689  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059478
#
# Epoch 70
# -------------------------------
# loss: 0.938112  [    0/10672]
# loss: 1.055696  [ 1600/10672]
# loss: 0.931204  [ 3200/10672]
# loss: 0.816723  [ 4800/10672]
# loss: 0.931129  [ 6400/10672]
# loss: 0.988731  [ 8000/10672]
# loss: 1.053669  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059458
#
# Epoch 71
# -------------------------------
# loss: 0.960014  [    0/10672]
# loss: 0.930860  [ 1600/10672]
# loss: 0.803799  [ 3200/10672]
# loss: 1.243475  [ 4800/10672]
# loss: 0.925606  [ 6400/10672]
# loss: 0.809429  [ 8000/10672]
# loss: 1.049115  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059520
#
# Epoch 72
# -------------------------------
# loss: 0.868828  [    0/10672]
# loss: 0.869545  [ 1600/10672]
# loss: 0.987801  [ 3200/10672]
# loss: 0.941076  [ 4800/10672]
# loss: 0.998784  [ 6400/10672]
# loss: 0.920946  [ 8000/10672]
# loss: 0.824624  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059389
#
# Epoch 73
# -------------------------------
# loss: 0.744134  [    0/10672]
# loss: 0.995645  [ 1600/10672]
# loss: 1.118665  [ 3200/10672]
# loss: 0.807767  [ 4800/10672]
# loss: 1.049052  [ 6400/10672]
# loss: 0.925917  [ 8000/10672]
# loss: 0.986038  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059524
#
# Epoch 74
# -------------------------------
# loss: 0.744447  [    0/10672]
# loss: 1.069661  [ 1600/10672]
# loss: 0.863479  [ 3200/10672]
# loss: 0.868696  [ 4800/10672]
# loss: 0.876657  [ 6400/10672]
# loss: 0.869357  [ 8000/10672]
# loss: 0.892502  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059454
#
# Epoch 75
# -------------------------------
# loss: 1.022009  [    0/10672]
# loss: 0.932331  [ 1600/10672]
# loss: 1.052639  [ 3200/10672]
# loss: 0.820409  [ 4800/10672]
# loss: 0.869111  [ 6400/10672]
# loss: 0.933745  [ 8000/10672]
# loss: 0.870200  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059483
#
# Epoch 76
# -------------------------------
# loss: 0.867668  [    0/10672]
# loss: 0.994248  [ 1600/10672]
# loss: 0.934681  [ 3200/10672]
# loss: 0.943596  [ 4800/10672]
# loss: 0.906229  [ 6400/10672]
# loss: 0.990468  [ 8000/10672]
# loss: 0.932948  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059373
#
# Epoch 77
# -------------------------------
# loss: 0.867854  [    0/10672]
# loss: 0.931067  [ 1600/10672]
# loss: 0.868784  [ 3200/10672]
# loss: 0.927405  [ 4800/10672]
# loss: 0.989754  [ 6400/10672]
# loss: 0.988320  [ 8000/10672]
# loss: 1.059601  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059452
#
# Epoch 78
# -------------------------------
# loss: 0.932608  [    0/10672]
# loss: 0.868226  [ 1600/10672]
# loss: 0.872615  [ 3200/10672]
# loss: 0.995007  [ 4800/10672]
# loss: 1.056924  [ 6400/10672]
# loss: 0.993527  [ 8000/10672]
# loss: 0.935257  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059370
#
# Epoch 79
# -------------------------------
# loss: 1.051432  [    0/10672]
# loss: 0.806636  [ 1600/10672]
# loss: 0.810601  [ 3200/10672]
# loss: 1.101346  [ 4800/10672]
# loss: 0.865460  [ 6400/10672]
# loss: 1.187920  [ 8000/10672]
# loss: 0.999195  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059376
#
# Epoch 80
# -------------------------------
# loss: 1.001783  [    0/10672]
# loss: 1.120330  [ 1600/10672]
# loss: 0.820354  [ 3200/10672]
# loss: 0.995013  [ 4800/10672]
# loss: 0.753444  [ 6400/10672]
# loss: 1.115213  [ 8000/10672]
# loss: 0.931213  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059526
#
# Epoch 81
# -------------------------------
# loss: 0.932800  [    0/10672]
# loss: 0.935593  [ 1600/10672]
# loss: 0.993398  [ 3200/10672]
# loss: 0.958413  [ 4800/10672]
# loss: 0.755552  [ 6400/10672]
# loss: 0.868778  [ 8000/10672]
# loss: 0.931242  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059372
#
# Epoch 82
# -------------------------------
# loss: 0.934499  [    0/10672]
# loss: 0.931426  [ 1600/10672]
# loss: 0.862236  [ 3200/10672]
# loss: 0.806290  [ 4800/10672]
# loss: 0.992642  [ 6400/10672]
# loss: 1.000194  [ 8000/10672]
# loss: 0.927172  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059528
#
# Epoch 83
# -------------------------------
# loss: 1.005684  [    0/10672]
# loss: 0.991107  [ 1600/10672]
# loss: 0.930204  [ 3200/10672]
# loss: 0.932944  [ 4800/10672]
# loss: 0.993669  [ 6400/10672]
# loss: 0.930103  [ 8000/10672]
# loss: 0.805723  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059369
#
# Epoch 84
# -------------------------------
# loss: 0.868944  [    0/10672]
# loss: 0.860812  [ 1600/10672]
# loss: 0.991254  [ 3200/10672]
# loss: 0.873659  [ 4800/10672]
# loss: 1.293779  [ 6400/10672]
# loss: 0.927299  [ 8000/10672]
# loss: 1.042843  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059367
#
# Epoch 85
# -------------------------------
# loss: 0.801164  [    0/10672]
# loss: 0.871263  [ 1600/10672]
# loss: 0.988935  [ 3200/10672]
# loss: 0.899083  [ 4800/10672]
# loss: 0.996931  [ 6400/10672]
# loss: 1.129294  [ 8000/10672]
# loss: 1.047727  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059456
#
# Epoch 86
# -------------------------------
# loss: 0.869786  [    0/10672]
# loss: 1.049667  [ 1600/10672]
# loss: 0.883402  [ 3200/10672]
# loss: 0.801438  [ 4800/10672]
# loss: 0.747805  [ 6400/10672]
# loss: 0.869031  [ 8000/10672]
# loss: 0.863724  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059446
#
# Epoch 87
# -------------------------------
# loss: 1.113547  [    0/10672]
# loss: 0.806600  [ 1600/10672]
# loss: 0.806467  [ 3200/10672]
# loss: 0.813421  [ 4800/10672]
# loss: 0.809443  [ 6400/10672]
# loss: 0.815724  [ 8000/10672]
# loss: 1.066496  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059602
#
# Epoch 88
# -------------------------------
# loss: 0.993136  [    0/10672]
# loss: 0.869366  [ 1600/10672]
# loss: 0.983818  [ 3200/10672]
# loss: 0.989158  [ 4800/10672]
# loss: 1.055377  [ 6400/10672]
# loss: 0.928339  [ 8000/10672]
# loss: 0.805098  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059520
#
# Epoch 89
# -------------------------------
# loss: 0.932982  [    0/10672]
# loss: 0.812774  [ 1600/10672]
# loss: 0.801635  [ 3200/10672]
# loss: 0.808332  [ 4800/10672]
# loss: 0.805964  [ 6400/10672]
# loss: 0.937300  [ 8000/10672]
# loss: 1.078637  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059606
#
# Epoch 90
# -------------------------------
# loss: 1.055422  [    0/10672]
# loss: 0.865462  [ 1600/10672]
# loss: 1.050823  [ 3200/10672]
# loss: 1.061415  [ 4800/10672]
# loss: 0.990230  [ 6400/10672]
# loss: 0.932109  [ 8000/10672]
# loss: 1.232079  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059599
#
# Epoch 91
# -------------------------------
# loss: 0.812371  [    0/10672]
# loss: 0.996084  [ 1600/10672]
# loss: 0.869933  [ 3200/10672]
# loss: 0.940035  [ 4800/10672]
# loss: 0.889096  [ 6400/10672]
# loss: 0.993320  [ 8000/10672]
# loss: 0.807500  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059366
#
# Epoch 92
# -------------------------------
# loss: 0.932444  [    0/10672]
# loss: 0.874797  [ 1600/10672]
# loss: 0.936089  [ 3200/10672]
# loss: 1.055869  [ 4800/10672]
# loss: 0.982968  [ 6400/10672]
# loss: 0.870827  [ 8000/10672]
# loss: 0.921581  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059446
#
# Epoch 93
# -------------------------------
# loss: 0.989825  [    0/10672]
# loss: 0.834067  [ 1600/10672]
# loss: 1.000922  [ 3200/10672]
# loss: 0.930740  [ 4800/10672]
# loss: 0.867499  [ 6400/10672]
# loss: 0.873371  [ 8000/10672]
# loss: 0.922944  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059443
#
# Epoch 94
# -------------------------------
# loss: 0.807965  [    0/10672]
# loss: 0.928677  [ 1600/10672]
# loss: 0.869078  [ 3200/10672]
# loss: 0.937121  [ 4800/10672]
# loss: 0.925937  [ 6400/10672]
# loss: 0.990961  [ 8000/10672]
# loss: 0.873576  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059521
#
# Epoch 95
# -------------------------------
# loss: 1.050324  [    0/10672]
# loss: 0.869097  [ 1600/10672]
# loss: 0.863220  [ 3200/10672]
# loss: 0.744309  [ 4800/10672]
# loss: 0.928724  [ 6400/10672]
# loss: 1.051550  [ 8000/10672]
# loss: 0.924356  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059369
#
# Epoch 96
# -------------------------------
# loss: 0.878110  [    0/10672]
# loss: 0.746050  [ 1600/10672]
# loss: 0.938381  [ 3200/10672]
# loss: 0.926224  [ 4800/10672]
# loss: 0.868308  [ 6400/10672]
# loss: 0.987905  [ 8000/10672]
# loss: 1.054297  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059443
#
# Epoch 97
# -------------------------------
# loss: 0.745995  [    0/10672]
# loss: 1.104258  [ 1600/10672]
# loss: 0.746798  [ 3200/10672]
# loss: 0.923703  [ 4800/10672]
# loss: 0.864935  [ 6400/10672]
# loss: 1.118569  [ 8000/10672]
# loss: 1.176290  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059447
#
# Epoch 98
# -------------------------------
# loss: 0.991214  [    0/10672]
# loss: 0.989104  [ 1600/10672]
# loss: 1.042761  [ 3200/10672]
# loss: 0.986586  [ 4800/10672]
# loss: 0.982502  [ 6400/10672]
# loss: 0.743782  [ 8000/10672]
# loss: 1.055660  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059448
#
# Epoch 99
# -------------------------------
# loss: 0.816747  [    0/10672]
# loss: 0.883841  [ 1600/10672]
# loss: 0.931553  [ 3200/10672]
# loss: 0.863936  [ 4800/10672]
# loss: 0.865276  [ 6400/10672]
# loss: 0.873105  [ 8000/10672]
# loss: 0.868633  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059442
#
# Epoch 100
# -------------------------------
# loss: 1.111906  [    0/10672]
# loss: 0.982637  [ 1600/10672]
# loss: 1.053183  [ 3200/10672]
# loss: 0.930584  [ 4800/10672]
# loss: 1.042106  [ 6400/10672]
# loss: 0.985353  [ 8000/10672]
# loss: 0.868052  [ 9600/10672]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.059526

# %%
plt.plot(loss_train, label="train")
plt.plot(loss_valid, label="valid")
plt.title("Loss")
plt.legend()
plt.show()

# %%
plt.plot(correct_train, label="train")
plt.plot(correct_valid, label="valid")
plt.title("Accuracy")
plt.legend()
plt.show()
