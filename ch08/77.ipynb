# %%
from os import path, mkdir
import pandas as pd
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torch.optim import SGD
import matplotlib.pyplot as plt
from time import time

base = "/content/drive/MyDrive/NLP100/ch08"

fp_train = "70/train.csv"
fp_valid = "70/valid.csv"
df_train = pd.read_csv(path.join(base, fp_train), index_col=0)
df_valid = pd.read_csv(path.join(base, fp_valid), index_col=0)
df_train.head()
# Out:
#                                                     TITLE  ...       299
# ID                                                         ...
# 311098  RPT-Fitch Updates EMEA Consumer ABS Rating Cri...  ... -0.043620
# 49198   Gurlitt Wants to Return Nazi-Looted Art, Suedd...  ... -0.078003
# 410578  UPDATE 1-Fairfax Financial, CEO probed over po...  ... -0.030084
# 270668  Angelina Jolie - Angelina Jolie Will Not Tight...  ...  0.098994
# 301656  Patent Officials Cancel the Washington Redskin...  ...  0.029964
#
# [5 rows x 307 columns]

# %%
X_train = torch.tensor(df_train[[str(r) for r in range(300)]].values.astype("float32"))
y_train = torch.tensor(df_train["CATEGORY"].values.astype("int"))
X_valid = torch.tensor(df_valid[[str(r) for r in range(300)]].values.astype("float32"))
y_valid = torch.tensor(df_valid["CATEGORY"].values.astype("int"))
print(X_train[:5])
print(y_train[:5])
# Out:
# tensor([[-0.0013,  0.0379, -0.0267,  ...,  0.0854,  0.0412, -0.0436],
#         [ 0.1195,  0.0482, -0.0516,  ..., -0.0930,  0.0493, -0.0780],
#         [-0.0272,  0.0079, -0.0188,  ...,  0.0608,  0.0242, -0.0301],
#         [ 0.0415,  0.0238, -0.1400,  ..., -0.0728, -0.0452,  0.0990],
#         [ 0.0851,  0.0319,  0.1310,  ..., -0.0540,  0.0016,  0.0300]])
# tensor([0, 2, 0, 2, 0])

# %%
class Model(nn.Module):
  def __init__(self):
    super().__init__()
    self.linear = nn.Linear(300, 4, bias=False)
    self.softmax = nn.Softmax(dim=1)

  def forward(self, x):
    y = self.linear(x)
    y = self.softmax(y)
    return y

# %%
learning_rate = 0.001
batch_sizes = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512]
loss_fn = nn.CrossEntropyLoss()

times = []
corrects = []
for batch_size in batch_sizes:
  num_workers = 2
  dataset_train = [(X_i, y_i) for X_i, y_i in zip(X_train, y_train)]
  dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True, num_workers=num_workers)
  dataset_valid = [(X_i, y_i) for X_i, y_i in zip(X_valid, y_valid)]
  dataloader_valid = DataLoader(dataset_valid, batch_size=batch_size, shuffle=True, num_workers=num_workers)
  
  model = Model()
  optimizer = SGD(model.parameters(), lr=learning_rate)

  start_time = time()
  for epoch in range(100):
    print(f"Epoch {epoch + 1}\n-------------------------------")
    size = len(dataloader_train.dataset)
    for batch, (X, y) in enumerate(dataloader_train):
      loss = loss_fn(model(X), y)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      if batch % 1000 == 0:
        loss, current = loss.item(), batch * len(X)
        print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

    size = len(dataloader_valid.dataset)
    loss, correct = 0, 0
    with torch.no_grad():
      for X, y in dataloader_valid:
        pred = model(X)
        loss += loss_fn(pred, y).item()
        correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    loss /= size
    correct /= size
    print(f"Test Error: \n Accuracy: {(100 * correct):>0.1f}%, Avg loss: {loss:>8f} \n")
  
  end_time = time()
  times.append((end_time - start_time) / 100)
  corrects.append(correct)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# loss: 1.153451  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.304789
#
# Epoch 14
# -------------------------------
# loss: 1.326409  [    0/10672]
# loss: 1.222788  [ 4000/10672]
# loss: 1.181647  [ 8000/10672]
# Test Error:
#  Accuracy: 78.4%, Avg loss: 0.302143
#
# Epoch 15
# -------------------------------
# loss: 1.183610  [    0/10672]
# loss: 1.153173  [ 4000/10672]
# loss: 1.169869  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.299419
#
# Epoch 16
# -------------------------------
# loss: 1.185138  [    0/10672]
# loss: 1.109399  [ 4000/10672]
# loss: 1.120158  [ 8000/10672]
# Test Error:
#  Accuracy: 78.4%, Avg loss: 0.297041
#
# Epoch 17
# -------------------------------
# loss: 1.002241  [    0/10672]
# loss: 1.186813  [ 4000/10672]
# loss: 1.398509  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.294702
#
# Epoch 18
# -------------------------------
# loss: 1.097152  [    0/10672]
# loss: 1.168812  [ 4000/10672]
# loss: 1.097800  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.292509
#
# Epoch 19
# -------------------------------
# loss: 1.105014  [    0/10672]
# loss: 1.225900  [ 4000/10672]
# loss: 1.301267  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.290406
#
# Epoch 20
# -------------------------------
# loss: 1.158722  [    0/10672]
# loss: 1.168549  [ 4000/10672]
# loss: 1.007671  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.288496
#
# Epoch 21
# -------------------------------
# loss: 1.295264  [    0/10672]
# loss: 0.983751  [ 4000/10672]
# loss: 1.076608  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.286689
#
# Epoch 22
# -------------------------------
# loss: 1.207716  [    0/10672]
# loss: 0.982326  [ 4000/10672]
# loss: 1.102425  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.284927
#
# Epoch 23
# -------------------------------
# loss: 1.251796  [    0/10672]
# loss: 1.130303  [ 4000/10672]
# loss: 0.946767  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.283368
#
# Epoch 24
# -------------------------------
# loss: 1.411334  [    0/10672]
# loss: 1.038543  [ 4000/10672]
# loss: 0.968920  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.281816
#
# Epoch 25
# -------------------------------
# loss: 1.134773  [    0/10672]
# loss: 1.276671  [ 4000/10672]
# loss: 1.176084  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.280406
#
# Epoch 26
# -------------------------------
# loss: 0.936281  [    0/10672]
# loss: 1.220713  [ 4000/10672]
# loss: 1.110120  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.279117
#
# Epoch 27
# -------------------------------
# loss: 1.153836  [    0/10672]
# loss: 1.120013  [ 4000/10672]
# loss: 1.077855  [ 8000/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.277864
#
# Epoch 28
# -------------------------------
# loss: 1.197902  [    0/10672]
# loss: 1.116371  [ 4000/10672]
# loss: 1.252486  [ 8000/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.276637
#
# Epoch 29
# -------------------------------
# loss: 1.164863  [    0/10672]
# loss: 1.040251  [ 4000/10672]
# loss: 0.981792  [ 8000/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.275545
#
# Epoch 30
# -------------------------------
# loss: 1.050199  [    0/10672]
# loss: 1.120544  [ 4000/10672]
# loss: 0.954661  [ 8000/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.274374
#
# Epoch 31
# -------------------------------
# loss: 1.107996  [    0/10672]
# loss: 1.143365  [ 4000/10672]
# loss: 1.067802  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.273380
#
# Epoch 32
# -------------------------------
# loss: 1.322750  [    0/10672]
# loss: 1.181732  [ 4000/10672]
# loss: 1.131002  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.272359
#
# Epoch 33
# -------------------------------
# loss: 1.203710  [    0/10672]
# loss: 0.988146  [ 4000/10672]
# loss: 0.887523  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.271698
#
# Epoch 34
# -------------------------------
# loss: 0.890402  [    0/10672]
# loss: 1.022071  [ 4000/10672]
# loss: 1.176687  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.270592
#
# Epoch 35
# -------------------------------
# loss: 0.939546  [    0/10672]
# loss: 0.905854  [ 4000/10672]
# loss: 1.071315  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.269899
#
# Epoch 36
# -------------------------------
# loss: 0.963633  [    0/10672]
# loss: 0.988778  [ 4000/10672]
# loss: 1.413955  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.269152
#
# Epoch 37
# -------------------------------
# loss: 0.987587  [    0/10672]
# loss: 1.029662  [ 4000/10672]
# loss: 0.967363  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.268318
#
# Epoch 38
# -------------------------------
# loss: 1.140023  [    0/10672]
# loss: 1.249061  [ 4000/10672]
# loss: 1.332901  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.267667
#
# Epoch 39
# -------------------------------
# loss: 1.013093  [    0/10672]
# loss: 1.109280  [ 4000/10672]
# loss: 1.000715  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.267010
#
# Epoch 40
# -------------------------------
# loss: 1.087992  [    0/10672]
# loss: 0.939867  [ 4000/10672]
# loss: 0.952029  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.266256
#
# Epoch 41
# -------------------------------
# loss: 1.078407  [    0/10672]
# loss: 1.302863  [ 4000/10672]
# loss: 0.899182  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.265672
#
# Epoch 42
# -------------------------------
# loss: 1.224344  [    0/10672]
# loss: 1.028384  [ 4000/10672]
# loss: 1.046445  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.265126
#
# Epoch 43
# -------------------------------
# loss: 0.901430  [    0/10672]
# loss: 0.899717  [ 4000/10672]
# loss: 1.185620  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.264641
#
# Epoch 44
# -------------------------------
# loss: 0.902526  [    0/10672]
# loss: 1.182666  [ 4000/10672]
# loss: 1.088010  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.264112
#
# Epoch 45
# -------------------------------
# loss: 1.081433  [    0/10672]
# loss: 1.306231  [ 4000/10672]
# loss: 0.953789  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.263487
#
# Epoch 46
# -------------------------------
# loss: 0.983743  [    0/10672]
# loss: 1.150016  [ 4000/10672]
# loss: 0.833572  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.262981
#
# Epoch 47
# -------------------------------
# loss: 1.246066  [    0/10672]
# loss: 1.083126  [ 4000/10672]
# loss: 1.469638  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.262528
#
# Epoch 48
# -------------------------------
# loss: 1.009440  [    0/10672]
# loss: 1.045825  [ 4000/10672]
# loss: 1.016482  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.261995
#
# Epoch 49
# -------------------------------
# loss: 1.317784  [    0/10672]
# loss: 0.857951  [ 4000/10672]
# loss: 1.299240  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.261653
#
# Epoch 50
# -------------------------------
# loss: 1.257675  [    0/10672]
# loss: 1.142547  [ 4000/10672]
# loss: 0.923429  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.261468
#
# Epoch 51
# -------------------------------
# loss: 0.884162  [    0/10672]
# loss: 0.883395  [ 4000/10672]
# loss: 1.114884  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.260907
#
# Epoch 52
# -------------------------------
# loss: 0.956548  [    0/10672]
# loss: 0.886247  [ 4000/10672]
# loss: 0.885232  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.260524
#
# Epoch 53
# -------------------------------
# loss: 1.328874  [    0/10672]
# loss: 0.958871  [ 4000/10672]
# loss: 1.258943  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.259979
#
# Epoch 54
# -------------------------------
# loss: 0.886026  [    0/10672]
# loss: 1.023469  [ 4000/10672]
# loss: 0.898853  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.259798
#
# Epoch 55
# -------------------------------
# loss: 0.960116  [    0/10672]
# loss: 0.865628  [ 4000/10672]
# loss: 1.200165  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.259424
#
# Epoch 56
# -------------------------------
# loss: 1.127346  [    0/10672]
# loss: 1.043561  [ 4000/10672]
# loss: 0.932091  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.259097
#
# Epoch 57
# -------------------------------
# loss: 1.076314  [    0/10672]
# loss: 0.988967  [ 4000/10672]
# loss: 1.010226  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.258664
#
# Epoch 58
# -------------------------------
# loss: 0.893605  [    0/10672]
# loss: 1.045899  [ 4000/10672]
# loss: 1.209604  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.258366
#
# Epoch 59
# -------------------------------
# loss: 1.137819  [    0/10672]
# loss: 0.847918  [ 4000/10672]
# loss: 0.914917  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.258040
#
# Epoch 60
# -------------------------------
# loss: 1.093015  [    0/10672]
# loss: 0.993072  [ 4000/10672]
# loss: 1.096587  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.257790
#
# Epoch 61
# -------------------------------
# loss: 0.842047  [    0/10672]
# loss: 1.186440  [ 4000/10672]
# loss: 0.940634  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.257454
#
# Epoch 62
# -------------------------------
# loss: 0.944278  [    0/10672]
# loss: 0.811746  [ 4000/10672]
# loss: 0.884173  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.257141
#
# Epoch 63
# -------------------------------
# loss: 1.087777  [    0/10672]
# loss: 1.301586  [ 4000/10672]
# loss: 1.143661  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.256877
#
# Epoch 64
# -------------------------------
# loss: 1.029125  [    0/10672]
# loss: 1.151483  [ 4000/10672]
# loss: 1.251808  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.256615
#
# Epoch 65
# -------------------------------
# loss: 0.872493  [    0/10672]
# loss: 0.886135  [ 4000/10672]
# loss: 1.205288  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.256629
#
# Epoch 66
# -------------------------------
# loss: 1.225110  [    0/10672]
# loss: 0.911102  [ 4000/10672]
# loss: 0.934719  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.256128
#
# Epoch 67
# -------------------------------
# loss: 1.122237  [    0/10672]
# loss: 0.845766  [ 4000/10672]
# loss: 0.990721  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.256026
#
# Epoch 68
# -------------------------------
# loss: 1.090135  [    0/10672]
# loss: 1.036559  [ 4000/10672]
# loss: 1.053507  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.255638
#
# Epoch 69
# -------------------------------
# loss: 1.251511  [    0/10672]
# loss: 0.911453  [ 4000/10672]
# loss: 1.226069  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.255403
#
# Epoch 70
# -------------------------------
# loss: 1.092021  [    0/10672]
# loss: 1.095386  [ 4000/10672]
# loss: 0.968498  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.255216
#
# Epoch 71
# -------------------------------
# loss: 0.921858  [    0/10672]
# loss: 1.082677  [ 4000/10672]
# loss: 1.116374  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.254990
#
# Epoch 72
# -------------------------------
# loss: 1.091375  [    0/10672]
# loss: 0.864965  [ 4000/10672]
# loss: 1.097000  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.255075
#
# Epoch 73
# -------------------------------
# loss: 0.825760  [    0/10672]
# loss: 1.057351  [ 4000/10672]
# loss: 1.296918  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.254620
#
# Epoch 74
# -------------------------------
# loss: 0.814137  [    0/10672]
# loss: 0.958501  [ 4000/10672]
# loss: 1.101917  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.254531
#
# Epoch 75
# -------------------------------
# loss: 1.007165  [    0/10672]
# loss: 1.303975  [ 4000/10672]
# loss: 1.104994  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.254180
#
# Epoch 76
# -------------------------------
# loss: 1.121133  [    0/10672]
# loss: 0.828901  [ 4000/10672]
# loss: 0.898115  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.253996
#
# Epoch 77
# -------------------------------
# loss: 1.071825  [    0/10672]
# loss: 0.809612  [ 4000/10672]
# loss: 1.269437  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.253823
#
# Epoch 78
# -------------------------------
# loss: 1.123783  [    0/10672]
# loss: 0.990700  [ 4000/10672]
# loss: 1.062187  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.253796
#
# Epoch 79
# -------------------------------
# loss: 0.814688  [    0/10672]
# loss: 1.321378  [ 4000/10672]
# loss: 1.189931  [ 8000/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.253606
#
# Epoch 80
# -------------------------------
# loss: 1.044133  [    0/10672]
# loss: 1.186685  [ 4000/10672]
# loss: 0.836150  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.253461
#
# Epoch 81
# -------------------------------
# loss: 1.136502  [    0/10672]
# loss: 1.110426  [ 4000/10672]
# loss: 1.006581  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.253166
#
# Epoch 82
# -------------------------------
# loss: 1.008826  [    0/10672]
# loss: 0.947061  [ 4000/10672]
# loss: 0.802285  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.252961
#
# Epoch 83
# -------------------------------
# loss: 0.884140  [    0/10672]
# loss: 0.767018  [ 4000/10672]
# loss: 0.876833  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.252981
#
# Epoch 84
# -------------------------------
# loss: 1.018515  [    0/10672]
# loss: 1.073911  [ 4000/10672]
# loss: 0.838683  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.252916
#
# Epoch 85
# -------------------------------
# loss: 1.202944  [    0/10672]
# loss: 0.823007  [ 4000/10672]
# loss: 1.058386  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.252500
#
# Epoch 86
# -------------------------------
# loss: 1.158809  [    0/10672]
# loss: 1.046960  [ 4000/10672]
# loss: 1.032409  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.252494
#
# Epoch 87
# -------------------------------
# loss: 1.178896  [    0/10672]
# loss: 1.270800  [ 4000/10672]
# loss: 1.181782  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.252206
#
# Epoch 88
# -------------------------------
# loss: 1.054666  [    0/10672]
# loss: 1.031508  [ 4000/10672]
# loss: 0.945549  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.252070
#
# Epoch 89
# -------------------------------
# loss: 0.871121  [    0/10672]
# loss: 0.990518  [ 4000/10672]
# loss: 1.167090  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.251919
#
# Epoch 90
# -------------------------------
# loss: 1.232628  [    0/10672]
# loss: 1.016284  [ 4000/10672]
# loss: 1.271772  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.251785
#
# Epoch 91
# -------------------------------
# loss: 0.827030  [    0/10672]
# loss: 0.880507  [ 4000/10672]
# loss: 0.874863  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.251974
#
# Epoch 92
# -------------------------------
# loss: 1.173102  [    0/10672]
# loss: 1.013622  [ 4000/10672]
# loss: 1.296995  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.251567
#
# Epoch 93
# -------------------------------
# loss: 1.005353  [    0/10672]
# loss: 0.923598  [ 4000/10672]
# loss: 1.025848  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.251416
#
# Epoch 94
# -------------------------------
# loss: 0.807923  [    0/10672]
# loss: 0.785478  [ 4000/10672]
# loss: 1.062965  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.251273
#
# Epoch 95
# -------------------------------
# loss: 1.035945  [    0/10672]
# loss: 1.118532  [ 4000/10672]
# loss: 1.196053  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.251132
#
# Epoch 96
# -------------------------------
# loss: 0.801797  [    0/10672]
# loss: 0.906058  [ 4000/10672]
# loss: 1.125121  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.251038
#
# Epoch 97
# -------------------------------
# loss: 1.016193  [    0/10672]
# loss: 1.073289  [ 4000/10672]
# loss: 0.860747  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.250959
#
# Epoch 98
# -------------------------------
# loss: 0.764723  [    0/10672]
# loss: 0.884304  [ 4000/10672]
# loss: 1.229346  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.250965
#
# Epoch 99
# -------------------------------
# loss: 1.033359  [    0/10672]
# loss: 1.042615  [ 4000/10672]
# loss: 1.035952  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.250681
#
# Epoch 100
# -------------------------------
# loss: 1.028145  [    0/10672]
# loss: 0.805413  [ 4000/10672]
# loss: 1.034312  [ 8000/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.250574
#
# Epoch 1
# -------------------------------
# loss: 1.377394  [    0/10672]
# loss: 1.374314  [ 8000/10672]
# Test Error:
#  Accuracy: 55.3%, Avg loss: 0.172119
#
# Epoch 2
# -------------------------------
# loss: 1.374106  [    0/10672]
# loss: 1.370638  [ 8000/10672]
# Test Error:
#  Accuracy: 62.2%, Avg loss: 0.171343
#
# Epoch 3
# -------------------------------
# loss: 1.361010  [    0/10672]
# loss: 1.373868  [ 8000/10672]
# Test Error:
#  Accuracy: 67.7%, Avg loss: 0.170555
#
# Epoch 4
# -------------------------------
# loss: 1.366862  [    0/10672]
# loss: 1.355582  [ 8000/10672]
# Test Error:
#  Accuracy: 70.9%, Avg loss: 0.169754
#
# Epoch 5
# -------------------------------
# loss: 1.401143  [    0/10672]
# loss: 1.357064  [ 8000/10672]
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.168947
#
# Epoch 6
# -------------------------------
# loss: 1.384838  [    0/10672]
# loss: 1.331461  [ 8000/10672]
# Test Error:
#  Accuracy: 74.1%, Avg loss: 0.168126
#
# Epoch 7
# -------------------------------
# loss: 1.345665  [    0/10672]
# loss: 1.339467  [ 8000/10672]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.167302
#
# Epoch 8
# -------------------------------
# loss: 1.335781  [    0/10672]
# loss: 1.338161  [ 8000/10672]
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.166468
#
# Epoch 9
# -------------------------------
# loss: 1.325751  [    0/10672]
# loss: 1.342913  [ 8000/10672]
# Test Error:
#  Accuracy: 76.5%, Avg loss: 0.165621
#
# Epoch 10
# -------------------------------
# loss: 1.281787  [    0/10672]
# loss: 1.273155  [ 8000/10672]
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.164787
#
# Epoch 11
# -------------------------------
# loss: 1.322838  [    0/10672]
# loss: 1.308484  [ 8000/10672]
# Test Error:
#  Accuracy: 77.3%, Avg loss: 0.163936
#
# Epoch 12
# -------------------------------
# loss: 1.294303  [    0/10672]
# loss: 1.309024  [ 8000/10672]
# Test Error:
#  Accuracy: 77.3%, Avg loss: 0.163087
#
# Epoch 13
# -------------------------------
# loss: 1.244374  [    0/10672]
# loss: 1.321211  [ 8000/10672]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.162265
#
# Epoch 14
# -------------------------------
# loss: 1.318516  [    0/10672]
# loss: 1.344899  [ 8000/10672]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.161427
#
# Epoch 15
# -------------------------------
# loss: 1.340450  [    0/10672]
# loss: 1.251360  [ 8000/10672]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.160589
#
# Epoch 16
# -------------------------------
# loss: 1.275319  [    0/10672]
# loss: 1.320719  [ 8000/10672]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.159772
#
# Epoch 17
# -------------------------------
# loss: 1.275298  [    0/10672]
# loss: 1.248759  [ 8000/10672]
# Test Error:
#  Accuracy: 77.9%, Avg loss: 0.158957
#
# Epoch 18
# -------------------------------
# loss: 1.323307  [    0/10672]
# loss: 1.284253  [ 8000/10672]
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.158148
#
# Epoch 19
# -------------------------------
# loss: 1.226699  [    0/10672]
# loss: 1.249084  [ 8000/10672]
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.157342
#
# Epoch 20
# -------------------------------
# loss: 1.221869  [    0/10672]
# loss: 1.186164  [ 8000/10672]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.156552
#
# Epoch 21
# -------------------------------
# loss: 1.299682  [    0/10672]
# loss: 1.198771  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.155778
#
# Epoch 22
# -------------------------------
# loss: 1.344799  [    0/10672]
# loss: 1.258009  [ 8000/10672]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.155057
#
# Epoch 23
# -------------------------------
# loss: 1.243147  [    0/10672]
# loss: 1.162045  [ 8000/10672]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.154319
#
# Epoch 24
# -------------------------------
# loss: 1.222381  [    0/10672]
# loss: 1.314233  [ 8000/10672]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.153575
#
# Epoch 25
# -------------------------------
# loss: 1.164436  [    0/10672]
# loss: 1.174272  [ 8000/10672]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.152868
#
# Epoch 26
# -------------------------------
# loss: 1.239270  [    0/10672]
# loss: 1.222493  [ 8000/10672]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.152179
#
# Epoch 27
# -------------------------------
# loss: 1.276606  [    0/10672]
# loss: 1.169447  [ 8000/10672]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.151484
#
# Epoch 28
# -------------------------------
# loss: 1.142327  [    0/10672]
# loss: 1.205871  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.150832
#
# Epoch 29
# -------------------------------
# loss: 1.264993  [    0/10672]
# loss: 1.273471  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.150157
#
# Epoch 30
# -------------------------------
# loss: 1.252191  [    0/10672]
# loss: 1.258724  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.149536
#
# Epoch 31
# -------------------------------
# loss: 1.153458  [    0/10672]
# loss: 1.132357  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.148923
#
# Epoch 32
# -------------------------------
# loss: 1.138561  [    0/10672]
# loss: 1.268504  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.148318
#
# Epoch 33
# -------------------------------
# loss: 1.090503  [    0/10672]
# loss: 1.048295  [ 8000/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.147745
#
# Epoch 34
# -------------------------------
# loss: 1.272538  [    0/10672]
# loss: 1.187927  [ 8000/10672]
# Test Error:
#  Accuracy: 78.4%, Avg loss: 0.147220
#
# Epoch 35
# -------------------------------
# loss: 1.164538  [    0/10672]
# loss: 1.078553  [ 8000/10672]
# Test Error:
#  Accuracy: 78.4%, Avg loss: 0.146643
#
# Epoch 36
# -------------------------------
# loss: 1.078243  [    0/10672]
# loss: 1.236819  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.146085
#
# Epoch 37
# -------------------------------
# loss: 1.005242  [    0/10672]
# loss: 1.134815  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.145620
#
# Epoch 38
# -------------------------------
# loss: 1.071820  [    0/10672]
# loss: 1.239102  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.145091
#
# Epoch 39
# -------------------------------
# loss: 1.177779  [    0/10672]
# loss: 1.098560  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.144594
#
# Epoch 40
# -------------------------------
# loss: 1.113427  [    0/10672]
# loss: 1.216222  [ 8000/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.144137
#
# Epoch 41
# -------------------------------
# loss: 1.235653  [    0/10672]
# loss: 1.187777  [ 8000/10672]
# Test Error:
#  Accuracy: 78.4%, Avg loss: 0.143628
#
# Epoch 42
# -------------------------------
# loss: 1.171670  [    0/10672]
# loss: 1.144667  [ 8000/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.143203
#
# Epoch 43
# -------------------------------
# loss: 1.069064  [    0/10672]
# loss: 1.162212  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.142808
#
# Epoch 44
# -------------------------------
# loss: 1.121953  [    0/10672]
# loss: 1.071747  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.142363
#
# Epoch 45
# -------------------------------
# loss: 1.328417  [    0/10672]
# loss: 1.075026  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.141984
#
# Epoch 46
# -------------------------------
# loss: 1.171258  [    0/10672]
# loss: 1.095119  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.141567
#
# Epoch 47
# -------------------------------
# loss: 1.139553  [    0/10672]
# loss: 1.079688  [ 8000/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.141188
#
# Epoch 48
# -------------------------------
# loss: 1.248951  [    0/10672]
# loss: 1.145024  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.140824
#
# Epoch 49
# -------------------------------
# loss: 1.044473  [    0/10672]
# loss: 1.194271  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.140466
#
# Epoch 50
# -------------------------------
# loss: 1.161508  [    0/10672]
# loss: 1.375716  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.140092
#
# Epoch 51
# -------------------------------
# loss: 0.957731  [    0/10672]
# loss: 1.098166  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.139763
#
# Epoch 52
# -------------------------------
# loss: 1.104324  [    0/10672]
# loss: 1.028743  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.139455
#
# Epoch 53
# -------------------------------
# loss: 0.992616  [    0/10672]
# loss: 0.979574  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.139095
#
# Epoch 54
# -------------------------------
# loss: 1.142630  [    0/10672]
# loss: 1.099116  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.138801
#
# Epoch 55
# -------------------------------
# loss: 1.017239  [    0/10672]
# loss: 1.197804  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.138489
#
# Epoch 56
# -------------------------------
# loss: 1.043884  [    0/10672]
# loss: 1.314341  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.138205
#
# Epoch 57
# -------------------------------
# loss: 1.018681  [    0/10672]
# loss: 1.100555  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.137940
#
# Epoch 58
# -------------------------------
# loss: 1.120219  [    0/10672]
# loss: 1.212716  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.137651
#
# Epoch 59
# -------------------------------
# loss: 1.117627  [    0/10672]
# loss: 1.033701  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.137364
#
# Epoch 60
# -------------------------------
# loss: 1.123733  [    0/10672]
# loss: 1.090376  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.137099
#
# Epoch 61
# -------------------------------
# loss: 1.288218  [    0/10672]
# loss: 1.098117  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.136896
#
# Epoch 62
# -------------------------------
# loss: 1.205319  [    0/10672]
# loss: 1.045805  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.136615
#
# Epoch 63
# -------------------------------
# loss: 1.055200  [    0/10672]
# loss: 1.079313  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.136367
#
# Epoch 64
# -------------------------------
# loss: 1.136261  [    0/10672]
# loss: 0.984293  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.136113
#
# Epoch 65
# -------------------------------
# loss: 0.954627  [    0/10672]
# loss: 1.070330  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.135910
#
# Epoch 66
# -------------------------------
# loss: 1.030737  [    0/10672]
# loss: 1.209466  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.135688
#
# Epoch 67
# -------------------------------
# loss: 0.951275  [    0/10672]
# loss: 1.094250  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.135452
#
# Epoch 68
# -------------------------------
# loss: 1.148619  [    0/10672]
# loss: 0.974180  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.135242
#
# Epoch 69
# -------------------------------
# loss: 0.962858  [    0/10672]
# loss: 1.207463  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.135049
#
# Epoch 70
# -------------------------------
# loss: 1.193344  [    0/10672]
# loss: 1.113214  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.134868
#
# Epoch 71
# -------------------------------
# loss: 1.094071  [    0/10672]
# loss: 1.095916  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.134689
#
# Epoch 72
# -------------------------------
# loss: 1.143036  [    0/10672]
# loss: 1.061640  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.134475
#
# Epoch 73
# -------------------------------
# loss: 1.221363  [    0/10672]
# loss: 1.104903  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.134306
#
# Epoch 74
# -------------------------------
# loss: 0.981643  [    0/10672]
# loss: 1.142470  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.134159
#
# Epoch 75
# -------------------------------
# loss: 0.889000  [    0/10672]
# loss: 1.007700  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.133930
#
# Epoch 76
# -------------------------------
# loss: 1.030293  [    0/10672]
# loss: 1.207832  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.133828
#
# Epoch 77
# -------------------------------
# loss: 1.179033  [    0/10672]
# loss: 1.078886  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.133575
#
# Epoch 78
# -------------------------------
# loss: 0.993657  [    0/10672]
# loss: 1.018542  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.133444
#
# Epoch 79
# -------------------------------
# loss: 1.044706  [    0/10672]
# loss: 1.280686  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.133275
#
# Epoch 80
# -------------------------------
# loss: 0.998364  [    0/10672]
# loss: 1.071617  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.133152
#
# Epoch 81
# -------------------------------
# loss: 0.988252  [    0/10672]
# loss: 1.200301  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.132995
#
# Epoch 82
# -------------------------------
# loss: 0.998282  [    0/10672]
# loss: 0.987497  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.132809
#
# Epoch 83
# -------------------------------
# loss: 1.177497  [    0/10672]
# loss: 1.212861  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.132687
#
# Epoch 84
# -------------------------------
# loss: 0.932589  [    0/10672]
# loss: 1.033579  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.132541
#
# Epoch 85
# -------------------------------
# loss: 1.105986  [    0/10672]
# loss: 1.079951  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.132381
#
# Epoch 86
# -------------------------------
# loss: 1.047831  [    0/10672]
# loss: 1.014544  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.132277
#
# Epoch 87
# -------------------------------
# loss: 0.989511  [    0/10672]
# loss: 1.195295  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.132093
#
# Epoch 88
# -------------------------------
# loss: 1.076141  [    0/10672]
# loss: 1.058770  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.131994
#
# Epoch 89
# -------------------------------
# loss: 0.946146  [    0/10672]
# loss: 1.105625  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.131846
#
# Epoch 90
# -------------------------------
# loss: 0.882029  [    0/10672]
# loss: 1.279701  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.131696
#
# Epoch 91
# -------------------------------
# loss: 0.935435  [    0/10672]
# loss: 1.063114  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.131594
#
# Epoch 92
# -------------------------------
# loss: 1.007111  [    0/10672]
# loss: 1.114667  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.131435
#
# Epoch 93
# -------------------------------
# loss: 1.245444  [    0/10672]
# loss: 1.115509  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.131359
#
# Epoch 94
# -------------------------------
# loss: 0.970322  [    0/10672]
# loss: 1.096572  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.131246
#
# Epoch 95
# -------------------------------
# loss: 0.896472  [    0/10672]
# loss: 1.030647  [ 8000/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.131141
#
# Epoch 96
# -------------------------------
# loss: 0.972055  [    0/10672]
# loss: 1.216251  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.130992
#
# Epoch 97
# -------------------------------
# loss: 0.972772  [    0/10672]
# loss: 0.944966  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.130922
#
# Epoch 98
# -------------------------------
# loss: 0.952093  [    0/10672]
# loss: 1.012823  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.130773
#
# Epoch 99
# -------------------------------
# loss: 1.076561  [    0/10672]
# loss: 0.978167  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.130663
#
# Epoch 100
# -------------------------------
# loss: 1.120478  [    0/10672]
# loss: 1.047926  [ 8000/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.130568
#
# Epoch 1
# -------------------------------
# loss: 1.392795  [    0/10672]
# Test Error:
#  Accuracy: 14.1%, Avg loss: 0.087435
#
# Epoch 2
# -------------------------------
# loss: 1.386095  [    0/10672]
# Test Error:
#  Accuracy: 22.0%, Avg loss: 0.087250
#
# Epoch 3
# -------------------------------
# loss: 1.386294  [    0/10672]
# Test Error:
#  Accuracy: 33.8%, Avg loss: 0.087062
#
# Epoch 4
# -------------------------------
# loss: 1.384128  [    0/10672]
# Test Error:
#  Accuracy: 48.8%, Avg loss: 0.086875
#
# Epoch 5
# -------------------------------
# loss: 1.381661  [    0/10672]
# Test Error:
#  Accuracy: 58.5%, Avg loss: 0.086687
#
# Epoch 6
# -------------------------------
# loss: 1.377668  [    0/10672]
# Test Error:
#  Accuracy: 64.2%, Avg loss: 0.086489
#
# Epoch 7
# -------------------------------
# loss: 1.371483  [    0/10672]
# Test Error:
#  Accuracy: 67.0%, Avg loss: 0.086300
#
# Epoch 8
# -------------------------------
# loss: 1.369229  [    0/10672]
# Test Error:
#  Accuracy: 68.8%, Avg loss: 0.086099
#
# Epoch 9
# -------------------------------
# loss: 1.372692  [    0/10672]
# Test Error:
#  Accuracy: 70.8%, Avg loss: 0.085907
#
# Epoch 10
# -------------------------------
# loss: 1.362195  [    0/10672]
# Test Error:
#  Accuracy: 71.7%, Avg loss: 0.085696
#
# Epoch 11
# -------------------------------
# loss: 1.366757  [    0/10672]
# Test Error:
#  Accuracy: 72.4%, Avg loss: 0.085492
#
# Epoch 12
# -------------------------------
# loss: 1.356140  [    0/10672]
# Test Error:
#  Accuracy: 73.2%, Avg loss: 0.085292
#
# Epoch 13
# -------------------------------
# loss: 1.351938  [    0/10672]
# Test Error:
#  Accuracy: 73.8%, Avg loss: 0.085089
#
# Epoch 14
# -------------------------------
# loss: 1.360151  [    0/10672]
# Test Error:
#  Accuracy: 74.3%, Avg loss: 0.084877
#
# Epoch 15
# -------------------------------
# loss: 1.343329  [    0/10672]
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.084680
#
# Epoch 16
# -------------------------------
# loss: 1.352378  [    0/10672]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.084467
#
# Epoch 17
# -------------------------------
# loss: 1.361238  [    0/10672]
# Test Error:
#  Accuracy: 75.6%, Avg loss: 0.084269
#
# Epoch 18
# -------------------------------
# loss: 1.336836  [    0/10672]
# Test Error:
#  Accuracy: 75.6%, Avg loss: 0.084072
#
# Epoch 19
# -------------------------------
# loss: 1.345789  [    0/10672]
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.083843
#
# Epoch 20
# -------------------------------
# loss: 1.326545  [    0/10672]
# Test Error:
#  Accuracy: 76.4%, Avg loss: 0.083610
#
# Epoch 21
# -------------------------------
# loss: 1.335223  [    0/10672]
# Test Error:
#  Accuracy: 76.5%, Avg loss: 0.083426
#
# Epoch 22
# -------------------------------
# loss: 1.344732  [    0/10672]
# Test Error:
#  Accuracy: 76.5%, Avg loss: 0.083208
#
# Epoch 23
# -------------------------------
# loss: 1.338044  [    0/10672]
# Test Error:
#  Accuracy: 76.5%, Avg loss: 0.082994
#
# Epoch 24
# -------------------------------
# loss: 1.345562  [    0/10672]
# Test Error:
#  Accuracy: 76.8%, Avg loss: 0.082807
#
# Epoch 25
# -------------------------------
# loss: 1.310931  [    0/10672]
# Test Error:
#  Accuracy: 77.1%, Avg loss: 0.082604
#
# Epoch 26
# -------------------------------
# loss: 1.323081  [    0/10672]
# Test Error:
#  Accuracy: 77.3%, Avg loss: 0.082382
#
# Epoch 27
# -------------------------------
# loss: 1.300835  [    0/10672]
# Test Error:
#  Accuracy: 77.3%, Avg loss: 0.082146
#
# Epoch 28
# -------------------------------
# loss: 1.307918  [    0/10672]
# Test Error:
#  Accuracy: 77.3%, Avg loss: 0.081903
#
# Epoch 29
# -------------------------------
# loss: 1.312120  [    0/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.081745
#
# Epoch 30
# -------------------------------
# loss: 1.277479  [    0/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.081522
#
# Epoch 31
# -------------------------------
# loss: 1.314048  [    0/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.081256
#
# Epoch 32
# -------------------------------
# loss: 1.308101  [    0/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.081074
#
# Epoch 33
# -------------------------------
# loss: 1.306745  [    0/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.080886
#
# Epoch 34
# -------------------------------
# loss: 1.297077  [    0/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.080715
#
# Epoch 35
# -------------------------------
# loss: 1.292838  [    0/10672]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.080465
#
# Epoch 36
# -------------------------------
# loss: 1.272385  [    0/10672]
# Test Error:
#  Accuracy: 77.6%, Avg loss: 0.080235
#
# Epoch 37
# -------------------------------
# loss: 1.285592  [    0/10672]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.080029
#
# Epoch 38
# -------------------------------
# loss: 1.318853  [    0/10672]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.079868
#
# Epoch 39
# -------------------------------
# loss: 1.290073  [    0/10672]
# Test Error:
#  Accuracy: 77.9%, Avg loss: 0.079643
#
# Epoch 40
# -------------------------------
# loss: 1.317648  [    0/10672]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.079462
#
# Epoch 41
# -------------------------------
# loss: 1.284372  [    0/10672]
# Test Error:
#  Accuracy: 77.9%, Avg loss: 0.079263
#
# Epoch 42
# -------------------------------
# loss: 1.267508  [    0/10672]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.079019
#
# Epoch 43
# -------------------------------
# loss: 1.310259  [    0/10672]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.078862
#
# Epoch 44
# -------------------------------
# loss: 1.304687  [    0/10672]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.078611
#
# Epoch 45
# -------------------------------
# loss: 1.328286  [    0/10672]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.078458
#
# Epoch 46
# -------------------------------
# loss: 1.280850  [    0/10672]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.078318
#
# Epoch 47
# -------------------------------
# loss: 1.207618  [    0/10672]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.078064
#
# Epoch 48
# -------------------------------
# loss: 1.234120  [    0/10672]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.077845
#
# Epoch 49
# -------------------------------
# loss: 1.247335  [    0/10672]
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.077734
#
# Epoch 50
# -------------------------------
# loss: 1.221382  [    0/10672]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.077527
#
# Epoch 51
# -------------------------------
# loss: 1.229221  [    0/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.077328
#
# Epoch 52
# -------------------------------
# loss: 1.188996  [    0/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.077116
#
# Epoch 53
# -------------------------------
# loss: 1.225864  [    0/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.076971
#
# Epoch 54
# -------------------------------
# loss: 1.167350  [    0/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.076799
#
# Epoch 55
# -------------------------------
# loss: 1.243859  [    0/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.076584
#
# Epoch 56
# -------------------------------
# loss: 1.200042  [    0/10672]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.076379
#
# Epoch 57
# -------------------------------
# loss: 1.239478  [    0/10672]
# Test Error:
#  Accuracy: 78.4%, Avg loss: 0.076252
#
# Epoch 58
# -------------------------------
# loss: 1.194508  [    0/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.076146
#
# Epoch 59
# -------------------------------
# loss: 1.229321  [    0/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.075944
#
# Epoch 60
# -------------------------------
# loss: 1.184804  [    0/10672]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.075716
#
# Epoch 61
# -------------------------------
# loss: 1.164148  [    0/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.075578
#
# Epoch 62
# -------------------------------
# loss: 1.197124  [    0/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.075531
#
# Epoch 63
# -------------------------------
# loss: 1.146606  [    0/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.075232
#
# Epoch 64
# -------------------------------
# loss: 1.143557  [    0/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.075130
#
# Epoch 65
# -------------------------------
# loss: 1.247837  [    0/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.074948
#
# Epoch 66
# -------------------------------
# loss: 1.167619  [    0/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.074823
#
# Epoch 67
# -------------------------------
# loss: 1.230548  [    0/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.074705
#
# Epoch 68
# -------------------------------
# loss: 1.209131  [    0/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.074468
#
# Epoch 69
# -------------------------------
# loss: 1.192443  [    0/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.074358
#
# Epoch 70
# -------------------------------
# loss: 1.203348  [    0/10672]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.074237
#
# Epoch 71
# -------------------------------
# loss: 1.239103  [    0/10672]
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.074123
#
# Epoch 72
# -------------------------------
# loss: 1.170854  [    0/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.073957
#
# Epoch 73
# -------------------------------
# loss: 1.259741  [    0/10672]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.073836
#
# Epoch 74
# -------------------------------
# loss: 1.140027  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.073703
#
# Epoch 75
# -------------------------------
# loss: 1.142918  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.073575
#
# Epoch 76
# -------------------------------
# loss: 1.221517  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.073357
#
# Epoch 77
# -------------------------------
# loss: 1.052619  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.073236
#
# Epoch 78
# -------------------------------
# loss: 1.156346  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.073134
#
# Epoch 79
# -------------------------------
# loss: 1.061251  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.073023
#
# Epoch 80
# -------------------------------
# loss: 1.148253  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.072868
#
# Epoch 81
# -------------------------------
# loss: 1.139380  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.072753
#
# Epoch 82
# -------------------------------
# loss: 1.152265  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.072684
#
# Epoch 83
# -------------------------------
# loss: 1.120969  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.072549
#
# Epoch 84
# -------------------------------
# loss: 1.112157  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.072453
#
# Epoch 85
# -------------------------------
# loss: 1.178508  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.072300
#
# Epoch 86
# -------------------------------
# loss: 1.174245  [    0/10672]
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.072191
#
# Epoch 87
# -------------------------------
# loss: 1.060409  [    0/10672]
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.072083
#
# Epoch 88
# -------------------------------
# loss: 1.163861  [    0/10672]
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.071889
#
# Epoch 89
# -------------------------------
# loss: 1.168942  [    0/10672]
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.071809
#
# Epoch 90
# -------------------------------
# loss: 1.210759  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.071701
#
# Epoch 91
# -------------------------------
# loss: 1.266741  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.071706
#
# Epoch 92
# -------------------------------
# loss: 1.128009  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.071512
#
# Epoch 93
# -------------------------------
# loss: 1.134883  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.071406
#
# Epoch 94
# -------------------------------
# loss: 1.053205  [    0/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.071381
#
# Epoch 95
# -------------------------------
# loss: 1.085959  [    0/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.071203
#
# Epoch 96
# -------------------------------
# loss: 1.153917  [    0/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.071142
#
# Epoch 97
# -------------------------------
# loss: 1.188190  [    0/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.071098
#
# Epoch 98
# -------------------------------
# loss: 1.165121  [    0/10672]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.070933
#
# Epoch 99
# -------------------------------
# loss: 1.133115  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.070816
#
# Epoch 100
# -------------------------------
# loss: 1.064097  [    0/10672]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.070800
#
# Epoch 1
# -------------------------------
# loss: 1.386985  [    0/10672]
# Test Error:
#  Accuracy: 27.1%, Avg loss: 0.043654
#
# Epoch 2
# -------------------------------
# loss: 1.386809  [    0/10672]
# Test Error:
#  Accuracy: 34.0%, Avg loss: 0.043607
#
# Epoch 3
# -------------------------------
# loss: 1.382972  [    0/10672]
# Test Error:
#  Accuracy: 41.2%, Avg loss: 0.043560
#
# Epoch 4
# -------------------------------
# loss: 1.381656  [    0/10672]
# Test Error:
#  Accuracy: 45.4%, Avg loss: 0.043513
#
# Epoch 5
# -------------------------------
# loss: 1.379373  [    0/10672]
# Test Error:
#  Accuracy: 48.7%, Avg loss: 0.043466
#
# Epoch 6
# -------------------------------
# loss: 1.381421  [    0/10672]
# Test Error:
#  Accuracy: 50.9%, Avg loss: 0.043417
#
# Epoch 7
# -------------------------------
# loss: 1.378587  [    0/10672]
# Test Error:
#  Accuracy: 52.5%, Avg loss: 0.043371
#
# Epoch 8
# -------------------------------
# loss: 1.379908  [    0/10672]
# Test Error:
#  Accuracy: 54.0%, Avg loss: 0.043324
#
# Epoch 9
# -------------------------------
# loss: 1.375367  [    0/10672]
# Test Error:
#  Accuracy: 55.8%, Avg loss: 0.043274
#
# Epoch 10
# -------------------------------
# loss: 1.376863  [    0/10672]
# Test Error:
#  Accuracy: 57.4%, Avg loss: 0.043226
#
# Epoch 11
# -------------------------------
# loss: 1.377175  [    0/10672]
# Test Error:
#  Accuracy: 58.3%, Avg loss: 0.043176
#
# Epoch 12
# -------------------------------
# loss: 1.367134  [    0/10672]
# Test Error:
#  Accuracy: 59.4%, Avg loss: 0.043129
#
# Epoch 13
# -------------------------------
# loss: 1.373544  [    0/10672]
# Test Error:
#  Accuracy: 60.8%, Avg loss: 0.043080
#
# Epoch 14
# -------------------------------
# loss: 1.362987  [    0/10672]
# Test Error:
#  Accuracy: 62.7%, Avg loss: 0.043032
#
# Epoch 15
# -------------------------------
# loss: 1.366266  [    0/10672]
# Test Error:
#  Accuracy: 63.9%, Avg loss: 0.042980
#
# Epoch 16
# -------------------------------
# loss: 1.365147  [    0/10672]
# Test Error:
#  Accuracy: 64.6%, Avg loss: 0.042930
#
# Epoch 17
# -------------------------------
# loss: 1.363209  [    0/10672]
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.042882
#
# Epoch 18
# -------------------------------
# loss: 1.359951  [    0/10672]
# Test Error:
#  Accuracy: 66.6%, Avg loss: 0.042830
#
# Epoch 19
# -------------------------------
# loss: 1.359901  [    0/10672]
# Test Error:
#  Accuracy: 67.3%, Avg loss: 0.042783
#
# Epoch 20
# -------------------------------
# loss: 1.353815  [    0/10672]
# Test Error:
#  Accuracy: 68.1%, Avg loss: 0.042732
#
# Epoch 21
# -------------------------------
# loss: 1.367926  [    0/10672]
# Test Error:
#  Accuracy: 69.6%, Avg loss: 0.042678
#
# Epoch 22
# -------------------------------
# loss: 1.355273  [    0/10672]
# Test Error:
#  Accuracy: 70.4%, Avg loss: 0.042631
#
# Epoch 23
# -------------------------------
# loss: 1.354341  [    0/10672]
# Test Error:
#  Accuracy: 71.3%, Avg loss: 0.042575
#
# Epoch 24
# -------------------------------
# loss: 1.350722  [    0/10672]
# Test Error:
#  Accuracy: 71.7%, Avg loss: 0.042523
#
# Epoch 25
# -------------------------------
# loss: 1.352245  [    0/10672]
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.042474
#
# Epoch 26
# -------------------------------
# loss: 1.349563  [    0/10672]
# Test Error:
#  Accuracy: 72.8%, Avg loss: 0.042422
#
# Epoch 27
# -------------------------------
# loss: 1.356123  [    0/10672]
# Test Error:
#  Accuracy: 73.2%, Avg loss: 0.042375
#
# Epoch 28
# -------------------------------
# loss: 1.353728  [    0/10672]
# Test Error:
#  Accuracy: 73.4%, Avg loss: 0.042319
#
# Epoch 29
# -------------------------------
# loss: 1.358918  [    0/10672]
# Test Error:
#  Accuracy: 74.0%, Avg loss: 0.042267
#
# Epoch 30
# -------------------------------
# loss: 1.355054  [    0/10672]
# Test Error:
#  Accuracy: 74.1%, Avg loss: 0.042216
#
# Epoch 31
# -------------------------------
# loss: 1.332501  [    0/10672]
# Test Error:
#  Accuracy: 74.5%, Avg loss: 0.042167
#
# Epoch 32
# -------------------------------
# loss: 1.350391  [    0/10672]
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.042115
#
# Epoch 33
# -------------------------------
# loss: 1.355285  [    0/10672]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 0.042060
#
# Epoch 34
# -------------------------------
# loss: 1.350200  [    0/10672]
# Test Error:
#  Accuracy: 74.8%, Avg loss: 0.042004
#
# Epoch 35
# -------------------------------
# loss: 1.330482  [    0/10672]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 0.041953
#
# Epoch 36
# -------------------------------
# loss: 1.331128  [    0/10672]
# Test Error:
# ...
#
# Epoch 71
# -------------------------------
# loss: 1.371361  [    0/10672]
# Test Error:
#  Accuracy: 56.5%, Avg loss: 0.006160
#
# Epoch 72
# -------------------------------
# loss: 1.373212  [    0/10672]
# Test Error:
#  Accuracy: 56.6%, Avg loss: 0.006162
#
# Epoch 73
# -------------------------------
# loss: 1.370299  [    0/10672]
# Test Error:
#  Accuracy: 56.9%, Avg loss: 0.006159
#
# Epoch 74
# -------------------------------
# loss: 1.370646  [    0/10672]
# Test Error:
#  Accuracy: 57.3%, Avg loss: 0.006159
#
# Epoch 75
# -------------------------------
# loss: 1.371532  [    0/10672]
# Test Error:
#  Accuracy: 57.3%, Avg loss: 0.006156
#
# Epoch 76
# -------------------------------
# loss: 1.372078  [    0/10672]
# Test Error:
#  Accuracy: 57.5%, Avg loss: 0.006156
#
# Epoch 77
# -------------------------------
# loss: 1.367859  [    0/10672]
# Test Error:
#  Accuracy: 57.6%, Avg loss: 0.006158
#
# Epoch 78
# -------------------------------
# loss: 1.371459  [    0/10672]
# Test Error:
#  Accuracy: 57.6%, Avg loss: 0.006156
#
# Epoch 79
# -------------------------------
# loss: 1.369095  [    0/10672]
# Test Error:
#  Accuracy: 57.9%, Avg loss: 0.006155
#
# Epoch 80
# -------------------------------
# loss: 1.368788  [    0/10672]
# Test Error:
#  Accuracy: 58.0%, Avg loss: 0.006155
#
# Epoch 81
# -------------------------------
# loss: 1.369728  [    0/10672]
# Test Error:
#  Accuracy: 58.2%, Avg loss: 0.006152
#
# Epoch 82
# -------------------------------
# loss: 1.368303  [    0/10672]
# Test Error:
#  Accuracy: 58.3%, Avg loss: 0.006150
#
# Epoch 83
# -------------------------------
# loss: 1.369451  [    0/10672]
# Test Error:
#  Accuracy: 58.5%, Avg loss: 0.006152
#
# Epoch 84
# -------------------------------
# loss: 1.369192  [    0/10672]
# Test Error:
#  Accuracy: 58.7%, Avg loss: 0.006148
#
# Epoch 85
# -------------------------------
# loss: 1.369371  [    0/10672]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.006150
#
# Epoch 86
# -------------------------------
# loss: 1.366339  [    0/10672]
# Test Error:
#  Accuracy: 59.1%, Avg loss: 0.006151
#
# Epoch 87
# -------------------------------
# loss: 1.370359  [    0/10672]
# Test Error:
#  Accuracy: 59.2%, Avg loss: 0.006144
#
# Epoch 88
# -------------------------------
# loss: 1.366762  [    0/10672]
# Test Error:
#  Accuracy: 59.4%, Avg loss: 0.006148
#
# Epoch 89
# -------------------------------
# loss: 1.365218  [    0/10672]
# Test Error:
#  Accuracy: 60.0%, Avg loss: 0.006146
#
# Epoch 90
# -------------------------------
# loss: 1.368407  [    0/10672]
# Test Error:
#  Accuracy: 60.3%, Avg loss: 0.006144
#
# Epoch 91
# -------------------------------
# loss: 1.365498  [    0/10672]
# Test Error:
#  Accuracy: 60.3%, Avg loss: 0.006143
#
# Epoch 92
# -------------------------------
# loss: 1.368530  [    0/10672]
# Test Error:
#  Accuracy: 60.6%, Avg loss: 0.006147
#
# Epoch 93
# -------------------------------
# loss: 1.368271  [    0/10672]
# Test Error:
#  Accuracy: 61.0%, Avg loss: 0.006141
#
# Epoch 94
# -------------------------------
# loss: 1.367479  [    0/10672]
# Test Error:
#  Accuracy: 61.2%, Avg loss: 0.006144
#
# Epoch 95
# -------------------------------
# loss: 1.362345  [    0/10672]
# Test Error:
#  Accuracy: 61.6%, Avg loss: 0.006141
#
# Epoch 96
# -------------------------------
# loss: 1.363457  [    0/10672]
# Test Error:
#  Accuracy: 61.7%, Avg loss: 0.006141
#
# Epoch 97
# -------------------------------
# loss: 1.363634  [    0/10672]
# Test Error:
#  Accuracy: 61.7%, Avg loss: 0.006140
#
# Epoch 98
# -------------------------------
# loss: 1.367129  [    0/10672]
# Test Error:
#  Accuracy: 62.0%, Avg loss: 0.006140
#
# Epoch 99
# -------------------------------
# loss: 1.364965  [    0/10672]
# Test Error:
#  Accuracy: 62.1%, Avg loss: 0.006138
#
# Epoch 100
# -------------------------------
# loss: 1.363330  [    0/10672]
# Test Error:
#  Accuracy: 62.2%, Avg loss: 0.006139
#
# Epoch 1
# -------------------------------
# loss: 1.389628  [    0/10672]
# Test Error:
#  Accuracy: 16.0%, Avg loss: 0.003126
#
# Epoch 2
# -------------------------------
# loss: 1.389758  [    0/10672]
# Test Error:
#  Accuracy: 16.2%, Avg loss: 0.003126
#
# Epoch 3
# -------------------------------
# loss: 1.389318  [    0/10672]
# Test Error:
#  Accuracy: 16.4%, Avg loss: 0.003125
#
# Epoch 4
# -------------------------------
# loss: 1.388618  [    0/10672]
# Test Error:
#  Accuracy: 16.7%, Avg loss: 0.003125
#
# Epoch 5
# -------------------------------
# loss: 1.388754  [    0/10672]
# Test Error:
#  Accuracy: 16.8%, Avg loss: 0.003125
#
# Epoch 6
# -------------------------------
# loss: 1.388985  [    0/10672]
# Test Error:
#  Accuracy: 16.9%, Avg loss: 0.003125
#
# Epoch 7
# -------------------------------
# loss: 1.388787  [    0/10672]
# Test Error:
#  Accuracy: 17.1%, Avg loss: 0.003125
#
# Epoch 8
# -------------------------------
# loss: 1.388664  [    0/10672]
# Test Error:
#  Accuracy: 17.5%, Avg loss: 0.003124
#
# Epoch 9
# -------------------------------
# loss: 1.389325  [    0/10672]
# Test Error:
#  Accuracy: 17.7%, Avg loss: 0.003124
#
# Epoch 10
# -------------------------------
# loss: 1.388671  [    0/10672]
# Test Error:
#  Accuracy: 17.8%, Avg loss: 0.003124
#
# Epoch 11
# -------------------------------
# loss: 1.388506  [    0/10672]
# Test Error:
#  Accuracy: 18.1%, Avg loss: 0.003124
#
# Epoch 12
# -------------------------------
# loss: 1.387815  [    0/10672]
# Test Error:
#  Accuracy: 18.2%, Avg loss: 0.003124
#
# Epoch 13
# -------------------------------
# loss: 1.388376  [    0/10672]
# Test Error:
#  Accuracy: 18.4%, Avg loss: 0.003124
#
# Epoch 14
# -------------------------------
# loss: 1.388344  [    0/10672]
# Test Error:
#  Accuracy: 18.9%, Avg loss: 0.003123
#
# Epoch 15
# -------------------------------
# loss: 1.388428  [    0/10672]
# Test Error:
#  Accuracy: 19.0%, Avg loss: 0.003123
#
# Epoch 16
# -------------------------------
# loss: 1.388410  [    0/10672]
# Test Error:
#  Accuracy: 19.0%, Avg loss: 0.003123
#
# Epoch 17
# -------------------------------
# loss: 1.388186  [    0/10672]
# Test Error:
#  Accuracy: 19.4%, Avg loss: 0.003123
#
# Epoch 18
# -------------------------------
# loss: 1.388001  [    0/10672]
# Test Error:
#  Accuracy: 19.6%, Avg loss: 0.003122
#
# Epoch 19
# -------------------------------
# loss: 1.388286  [    0/10672]
# Test Error:
#  Accuracy: 19.9%, Avg loss: 0.003122
#
# Epoch 20
# -------------------------------
# loss: 1.387710  [    0/10672]
# Test Error:
#  Accuracy: 19.6%, Avg loss: 0.003122
#
# Epoch 21
# -------------------------------
# loss: 1.387647  [    0/10672]
# Test Error:
#  Accuracy: 19.7%, Avg loss: 0.003122
#
# Epoch 22
# -------------------------------
# loss: 1.387472  [    0/10672]
# Test Error:
#  Accuracy: 19.9%, Avg loss: 0.003122
#
# Epoch 23
# -------------------------------
# loss: 1.387921  [    0/10672]
# Test Error:
#  Accuracy: 20.4%, Avg loss: 0.003121
#
# Epoch 24
# -------------------------------
# loss: 1.386850  [    0/10672]
# Test Error:
#  Accuracy: 20.8%, Avg loss: 0.003121
#
# Epoch 25
# -------------------------------
# loss: 1.387328  [    0/10672]
# Test Error:
#  Accuracy: 21.4%, Avg loss: 0.003121
#
# Epoch 26
# -------------------------------
# loss: 1.387430  [    0/10672]
# Test Error:
#  Accuracy: 22.0%, Avg loss: 0.003121
#
# Epoch 27
# -------------------------------
# loss: 1.386793  [    0/10672]
# Test Error:
#  Accuracy: 22.2%, Avg loss: 0.003121
#
# Epoch 28
# -------------------------------
# loss: 1.387293  [    0/10672]
# Test Error:
#  Accuracy: 22.3%, Avg loss: 0.003120
#
# Epoch 29
# -------------------------------
# loss: 1.387279  [    0/10672]
# Test Error:
#  Accuracy: 22.6%, Avg loss: 0.003120
#
# Epoch 30
# -------------------------------
# loss: 1.387945  [    0/10672]
# Test Error:
#  Accuracy: 22.8%, Avg loss: 0.003120
#
# Epoch 31
# -------------------------------
# loss: 1.387142  [    0/10672]
# Test Error:
#  Accuracy: 22.9%, Avg loss: 0.003120
#
# Epoch 32
# -------------------------------
# loss: 1.386526  [    0/10672]
# Test Error:
#  Accuracy: 23.5%, Avg loss: 0.003120
#
# Epoch 33
# -------------------------------
# loss: 1.386820  [    0/10672]
# Test Error:
#  Accuracy: 23.5%, Avg loss: 0.003119
#
# Epoch 34
# -------------------------------
# loss: 1.386247  [    0/10672]
# Test Error:
#  Accuracy: 23.7%, Avg loss: 0.003119
#
# Epoch 35
# -------------------------------
# loss: 1.386176  [    0/10672]
# Test Error:
#  Accuracy: 23.8%, Avg loss: 0.003119
#
# Epoch 36
# -------------------------------
# loss: 1.386194  [    0/10672]
# Test Error:
#  Accuracy: 24.0%, Avg loss: 0.003119
#
# Epoch 37
# -------------------------------
# loss: 1.386296  [    0/10672]
# Test Error:
#  Accuracy: 24.2%, Avg loss: 0.003119
#
# Epoch 38
# -------------------------------
# loss: 1.385282  [    0/10672]
# Test Error:
#  Accuracy: 24.6%, Avg loss: 0.003118
#
# Epoch 39
# -------------------------------
# loss: 1.386065  [    0/10672]
# Test Error:
#  Accuracy: 24.7%, Avg loss: 0.003118
#
# Epoch 40
# -------------------------------
# loss: 1.386279  [    0/10672]
# Test Error:
#  Accuracy: 25.1%, Avg loss: 0.003118
#
# Epoch 41
# -------------------------------
# loss: 1.385873  [    0/10672]
# Test Error:
#  Accuracy: 25.4%, Avg loss: 0.003118
#
# Epoch 42
# -------------------------------
# loss: 1.385453  [    0/10672]
# Test Error:
#  Accuracy: 25.7%, Avg loss: 0.003117
#
# Epoch 43
# -------------------------------
# loss: 1.385803  [    0/10672]
# Test Error:
#  Accuracy: 25.9%, Avg loss: 0.003117
#
# Epoch 44
# -------------------------------
# loss: 1.385798  [    0/10672]
# Test Error:
#  Accuracy: 26.5%, Avg loss: 0.003117
#
# Epoch 45
# -------------------------------
# loss: 1.385035  [    0/10672]
# Test Error:
#  Accuracy: 27.0%, Avg loss: 0.003117
#
# Epoch 46
# -------------------------------
# loss: 1.385209  [    0/10672]
# Test Error:
#  Accuracy: 27.3%, Avg loss: 0.003116
#
# Epoch 47
# -------------------------------
# loss: 1.385152  [    0/10672]
# Test Error:
#  Accuracy: 27.4%, Avg loss: 0.003116
#
# Epoch 48
# -------------------------------
# loss: 1.385876  [    0/10672]
# Test Error:
#  Accuracy: 27.7%, Avg loss: 0.003116
#
# Epoch 49
# -------------------------------
# loss: 1.384884  [    0/10672]
# Test Error:
#  Accuracy: 27.8%, Avg loss: 0.003116
#
# Epoch 50
# -------------------------------
# loss: 1.385228  [    0/10672]
# Test Error:
#  Accuracy: 28.2%, Avg loss: 0.003116
#
# Epoch 51
# -------------------------------
# loss: 1.385181  [    0/10672]
# Test Error:
#  Accuracy: 28.7%, Avg loss: 0.003115
#
# Epoch 52
# -------------------------------
# loss: 1.385532  [    0/10672]
# Test Error:
#  Accuracy: 29.2%, Avg loss: 0.003115
#
# Epoch 53
# -------------------------------
# loss: 1.384528  [    0/10672]
# Test Error:
#  Accuracy: 29.5%, Avg loss: 0.003115
#
# Epoch 54
# -------------------------------
# loss: 1.384296  [    0/10672]
# Test Error:
#  Accuracy: 29.6%, Avg loss: 0.003115
#
# Epoch 55
# -------------------------------
# loss: 1.384040  [    0/10672]
# Test Error:
#  Accuracy: 29.9%, Avg loss: 0.003115
#
# Epoch 56
# -------------------------------
# loss: 1.384759  [    0/10672]
# Test Error:
#  Accuracy: 30.2%, Avg loss: 0.003115
#
# Epoch 57
# -------------------------------
# loss: 1.384483  [    0/10672]
# Test Error:
#  Accuracy: 30.4%, Avg loss: 0.003115
#
# Epoch 58
# -------------------------------
# loss: 1.384465  [    0/10672]
# Test Error:
#  Accuracy: 30.5%, Avg loss: 0.003114
#
# Epoch 59
# -------------------------------
# loss: 1.384246  [    0/10672]
# Test Error:
#  Accuracy: 30.4%, Avg loss: 0.003114
#
# Epoch 60
# -------------------------------
# loss: 1.383459  [    0/10672]
# Test Error:
#  Accuracy: 30.4%, Avg loss: 0.003114
#
# Epoch 61
# -------------------------------
# loss: 1.382930  [    0/10672]
# Test Error:
#  Accuracy: 30.8%, Avg loss: 0.003114
#
# Epoch 62
# -------------------------------
# loss: 1.384214  [    0/10672]
# Test Error:
#  Accuracy: 30.9%, Avg loss: 0.003113
#
# Epoch 63
# -------------------------------
# loss: 1.384378  [    0/10672]
# Test Error:
#  Accuracy: 31.1%, Avg loss: 0.003113
#
# Epoch 64
# -------------------------------
# loss: 1.384726  [    0/10672]
# Test Error:
#  Accuracy: 31.7%, Avg loss: 0.003113
#
# Epoch 65
# -------------------------------
# loss: 1.383432  [    0/10672]
# Test Error:
#  Accuracy: 32.1%, Avg loss: 0.003113
#
# Epoch 66
# -------------------------------
# loss: 1.383540  [    0/10672]
# Test Error:
#  Accuracy: 32.7%, Avg loss: 0.003112
#
# Epoch 67
# -------------------------------
# loss: 1.382693  [    0/10672]
# Test Error:
#  Accuracy: 32.9%, Avg loss: 0.003112
#
# Epoch 68
# -------------------------------
# loss: 1.383157  [    0/10672]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 0.003112
#
# Epoch 69
# -------------------------------
# loss: 1.382875  [    0/10672]
# Test Error:
#  Accuracy: 33.6%, Avg loss: 0.003112
#
# Epoch 70
# -------------------------------
# loss: 1.382886  [    0/10672]
# Test Error:
#  Accuracy: 33.7%, Avg loss: 0.003111
#
# Epoch 71
# -------------------------------
# loss: 1.383193  [    0/10672]
# Test Error:
#  Accuracy: 33.9%, Avg loss: 0.003112
#
# Epoch 72
# -------------------------------
# loss: 1.382074  [    0/10672]
# Test Error:
#  Accuracy: 34.0%, Avg loss: 0.003111
#
# Epoch 73
# -------------------------------
# loss: 1.383358  [    0/10672]
# Test Error:
#  Accuracy: 34.3%, Avg loss: 0.003111
#
# Epoch 74
# -------------------------------
# loss: 1.383299  [    0/10672]
# Test Error:
#  Accuracy: 34.6%, Avg loss: 0.003111
#
# Epoch 75
# -------------------------------
# loss: 1.383534  [    0/10672]
# Test Error:
#  Accuracy: 35.2%, Avg loss: 0.003111
#
# Epoch 76
# -------------------------------
# loss: 1.383199  [    0/10672]
# Test Error:
#  Accuracy: 35.2%, Avg loss: 0.003110
#
# Epoch 77
# -------------------------------
# loss: 1.382641  [    0/10672]
# Test Error:
#  Accuracy: 35.2%, Avg loss: 0.003110
#
# Epoch 78
# -------------------------------
# loss: 1.382475  [    0/10672]
# Test Error:
#  Accuracy: 35.5%, Avg loss: 0.003110
#
# Epoch 79
# -------------------------------
# loss: 1.381758  [    0/10672]
# Test Error:
#  Accuracy: 35.7%, Avg loss: 0.003109
#
# Epoch 80
# -------------------------------
# loss: 1.382062  [    0/10672]
# Test Error:
#  Accuracy: 36.0%, Avg loss: 0.003110
#
# Epoch 81
# -------------------------------
# loss: 1.381616  [    0/10672]
# Test Error:
#  Accuracy: 36.2%, Avg loss: 0.003109
#
# Epoch 82
# -------------------------------
# loss: 1.382318  [    0/10672]
# Test Error:
#  Accuracy: 36.4%, Avg loss: 0.003109
#
# Epoch 83
# -------------------------------
# loss: 1.382168  [    0/10672]
# Test Error:
#  Accuracy: 36.6%, Avg loss: 0.003109
#
# Epoch 84
# -------------------------------
# loss: 1.381811  [    0/10672]
# Test Error:
#  Accuracy: 37.1%, Avg loss: 0.003109
#
# Epoch 85
# -------------------------------
# loss: 1.382492  [    0/10672]
# Test Error:
#  Accuracy: 37.4%, Avg loss: 0.003108
#
# Epoch 86
# -------------------------------
# loss: 1.382618  [    0/10672]
# Test Error:
#  Accuracy: 37.6%, Avg loss: 0.003108
#
# Epoch 87
# -------------------------------
# loss: 1.381071  [    0/10672]
# Test Error:
#  Accuracy: 37.8%, Avg loss: 0.003108
#
# Epoch 88
# -------------------------------
# loss: 1.381384  [    0/10672]
# Test Error:
#  Accuracy: 38.1%, Avg loss: 0.003108
#
# Epoch 89
# -------------------------------
# loss: 1.381484  [    0/10672]
# Test Error:
#  Accuracy: 38.4%, Avg loss: 0.003108
#
# Epoch 90
# -------------------------------
# loss: 1.381218  [    0/10672]
# Test Error:
#  Accuracy: 39.0%, Avg loss: 0.003108
#
# Epoch 91
# -------------------------------
# loss: 1.381752  [    0/10672]
# Test Error:
#  Accuracy: 39.1%, Avg loss: 0.003107
#
# Epoch 92
# -------------------------------
# loss: 1.381054  [    0/10672]
# Test Error:
#  Accuracy: 39.5%, Avg loss: 0.003107
#
# Epoch 93
# -------------------------------
# loss: 1.380468  [    0/10672]
# Test Error:
#  Accuracy: 39.7%, Avg loss: 0.003107
#
# Epoch 94
# -------------------------------
# loss: 1.381024  [    0/10672]
# Test Error:
#  Accuracy: 40.0%, Avg loss: 0.003107
#
# Epoch 95
# -------------------------------
# loss: 1.380884  [    0/10672]
# Test Error:
#  Accuracy: 40.2%, Avg loss: 0.003107
#
# Epoch 96
# -------------------------------
# loss: 1.380891  [    0/10672]
# Test Error:
#  Accuracy: 40.4%, Avg loss: 0.003106
#
# Epoch 97
# -------------------------------
# loss: 1.380870  [    0/10672]
# Test Error:
#  Accuracy: 40.5%, Avg loss: 0.003106
#
# Epoch 98
# -------------------------------
# loss: 1.381311  [    0/10672]
# Test Error:
#  Accuracy: 40.7%, Avg loss: 0.003106
#
# Epoch 99
# -------------------------------
# loss: 1.380997  [    0/10672]
# Test Error:
#  Accuracy: 41.1%, Avg loss: 0.003105
#
# Epoch 100
# -------------------------------
# loss: 1.379299  [    0/10672]
# Test Error:
#  Accuracy: 41.2%, Avg loss: 0.003105

# %%
plt.plot(batch_sizes, times)
plt.xlabel("batch size")
plt.ylabel("time")
plt.xscale("log")
plt.show()

# %%
plt.plot(batch_sizes, corrects)
plt.xlabel("batch size")
plt.ylabel("accuracy")
plt.xscale("log")
plt.show()
