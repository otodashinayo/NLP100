# %%
from os import path
import pandas as pd
from tqdm.notebook import tqdm
import torch
import numpy as np
from time import time
base = "/content/drive/MyDrive/NLP100/ch08"

fp_train = "70/train.csv"
fp_valid = "70/valid.csv"
df_train = pd.read_csv(path.join(base, fp_train), index_col=0)
df_valid = pd.read_csv(path.join(base, fp_valid), index_col=0)
df_train.head()
# Out:
#                                                     TITLE  ...       299
# ID                                                         ...
# 311098  RPT-Fitch Updates EMEA Consumer ABS Rating Cri...  ... -0.043620
# 49198   Gurlitt Wants to Return Nazi-Looted Art, Suedd...  ... -0.078003
# 410578  UPDATE 1-Fairfax Financial, CEO probed over po...  ... -0.030084
# 270668  Angelina Jolie - Angelina Jolie Will Not Tight...  ...  0.098994
# 301656  Patent Officials Cancel the Washington Redskin...  ...  0.029964
#
# [5 rows x 307 columns]

# %%
X_train = torch.tensor(df_train[[str(r) for r in range(300)]].values.astype("float32"))
y_train = torch.tensor(df_train["CATEGORY"].values.astype("int"))
X_valid = torch.tensor(df_valid[[str(r) for r in range(300)]].values.astype("float32"))
y_valid = torch.tensor(df_valid["CATEGORY"].values.astype("int"))
print(X_train[:5])
print(y_train[:5])
# Out:
# tensor([[-0.0013,  0.0379, -0.0267,  ...,  0.0854,  0.0412, -0.0436],
#         [ 0.1195,  0.0482, -0.0516,  ..., -0.0930,  0.0493, -0.0780],
#         [-0.0272,  0.0079, -0.0188,  ...,  0.0608,  0.0242, -0.0301],
#         [ 0.0415,  0.0238, -0.1400,  ..., -0.0728, -0.0452,  0.0990],
#         [ 0.0851,  0.0319,  0.1310,  ..., -0.0540,  0.0016,  0.0300]])
# tensor([0, 2, 0, 2, 0])

# %%
model = torch.nn.Sequential(
    torch.nn.Linear(300, 4),
    torch.nn.Softmax(dim=1)
)
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)


class MyDataset(torch.utils.data.Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, i):
        return (self.X[i], self.y[i])


dataset_train = MyDataset(X_train, y_train)
for batch_size in np.power(2, np.arange(10)):
  start_time = time()
  dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size=int(batch_size))
  for epoch in tqdm(range(1, 201)):
    for (inputs, targets) in dataloader_train:
      optimizer.zero_grad()
      loss_train = loss_fn(model(inputs), targets)
      loss_train.backward()
      optimizer.step()
  loss_valid = loss_fn(model(X_valid), y_valid)
  with torch.no_grad():
    total_train = len(y_train)
    correct_train = (torch.argmax(model(X_train), dim=1) == y_train).sum().item()
    accuracy_train = correct_train / total_train
  with torch.no_grad():
    total_valid = len(y_valid)
    correct_valid = (torch.argmax(model(X_valid), dim=1) == y_valid).sum().item()
    accuracy_valid = correct_valid / total_valid
    end_time = time()
  print(f"batch size: {batch_size}, pass time: {end_time - start_time}")
  print(f"loss train: {loss_train.item()}, loss valid: {loss_valid.item()}")
  print(f"accuracy train: {accuracy_train}, accuracy valid: {accuracy_valid}")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# batch size: 1, pass time: 779.1387460231781
# loss train: 0.743672251701355, loss valid: 0.8537901639938354
# accuracy train: 0.9293478260869565, accuracy valid: 0.8928035982008995
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# batch size: 2, pass time: 408.591632604599
# loss train: 0.7436690330505371, loss valid: 0.854312539100647
# accuracy train: 0.9356259370314842, accuracy valid: 0.8913043478260869
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# batch size: 4, pass time: 212.3822259902954
# loss train: 0.743668794631958, loss valid: 0.8546850681304932
# accuracy train: 0.9364692653673163, accuracy valid: 0.8898050974512743
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# batch size: 8, pass time: 114.49429893493652
# loss train: 0.7705494165420532, loss valid: 0.8548383712768555
# accuracy train: 0.9375, accuracy valid: 0.889055472263868
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# batch size: 16, pass time: 64.00839686393738
# loss train: 0.8773689270019531, loss valid: 0.8549051880836487
# accuracy train: 0.9375937031484258, accuracy valid: 0.8905547226386806
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# batch size: 32, pass time: 39.142091274261475
# loss train: 0.8750027418136597, loss valid: 0.8549447655677795
# accuracy train: 0.9376874062968515, accuracy valid: 0.8913043478260869
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# batch size: 64, pass time: 25.83516764640808
# loss train: 0.8584399223327637, loss valid: 0.8549611568450928
# accuracy train: 0.9377811094452774, accuracy valid: 0.8913043478260869
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# batch size: 128, pass time: 19.095775842666626
# loss train: 0.8577511310577393, loss valid: 0.8549554944038391
# accuracy train: 0.9377811094452774, accuracy valid: 0.8913043478260869
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# batch size: 256, pass time: 17.56794047355652
# loss train: 0.8393977880477905, loss valid: 0.8549706935882568
# accuracy train: 0.9377811094452774, accuracy valid: 0.8913043478260869
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# batch size: 512, pass time: 15.623241424560547
# loss train: 0.8310084939002991, loss valid: 0.8549717664718628
# accuracy train: 0.9377811094452774, accuracy valid: 0.8913043478260869
